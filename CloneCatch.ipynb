# %%
import os
import shutil
import numpy as np
from collections import defaultdict
from PIL import Image
import pillow_heif
from keras.applications import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing.image import img_to_array
from keras.models import Model
# Out:
# Num GPUs Available:  0

# %% [markdown]
# # Convert HEIC to JPG

# %%
import os
import shutil
from PIL import Image
import pillow_heif

def convert_to_jpeg(image_folder):
    print(f"Converting images in folder: {image_folder}")
    
    # Create a folder for videos if it doesn't exist
    videos_folder = os.path.join(image_folder, 'videos')
    os.makedirs(videos_folder, exist_ok=True)

    # List files in the image folder for verification
    print("Files in the folder:", os.listdir(image_folder))

    # Loop through all files in the image folder
    for image_file in os.listdir(image_folder):
        # Get the full path of the image file
        image_path = os.path.join(image_folder, image_file)

        # Process only files
        if os.path.isfile(image_path):
            # Get the file extension
            _, ext = os.path.splitext(image_file)

            # Check if it's a video file
            if ext.lower() in ['.mp4', '.avi', '.mov', '.mkv', '.wmv', '.flv']:
                # Move video file to the videos folder
                shutil.move(image_path, os.path.join(videos_folder, image_file))
                print(f"Moved video file to {videos_folder}: {image_file}")
            # Convert HEIC and other images to JPEG
            elif ext.lower() in ['.heic', '.jpeg', '.jpg', '.png', '.gif']:
                try:
                    # Open HEIC image
                    if ext.lower() == '.heic':
                        heif_file = pillow_heif.open_heif(image_path)
                        img = Image.frombytes('RGB', heif_file.size, heif_file.data)
                    else:
                        img = Image.open(image_path)

                    # Convert image to RGB (JPEG format)
                    img = img.convert('RGB')
                    
                    # Save the image as JPEG in the same folder
                    output_file = os.path.join(image_folder, f"{os.path.splitext(image_file)[0]}.jpg")
                    img.save(output_file, format='JPEG')
                    print(f"Converted {image_file} to {output_file}")

                    # If the conversion is successful, delete the original HEIC file
                    if ext.lower() == '.heic':
                        os.remove(image_path)
                        print(f"Deleted original HEIC file: {image_file}")
                except Exception as e:
                    print(f"Error converting {image_file}: {e}")

# Define paths
image_folder = './images/'  # Folder containing images

# Convert images
convert_to_jpeg(image_folder)
# Out:
# Converting images in folder: ./images/
# Files in the folder: ['IMG_0323.MOV', 'IMG_0324.MOV', 'IMG_0326.MOV', 'IMG_0327.MOV', 'IMG_0328.MOV', 'IMG_0329.MOV', 'IMG_0330.MOV', 'IMG_0331.MOV', 'IMG_0332.MOV', 'IMG_0333(1).HEIC', 'IMG_0333.HEIC', 'IMG_0334.HEIC', 'IMG_0335.HEIC', 'IMG_0336.HEIC', 'IMG_0337.HEIC', 'IMG_0338.MOV', 'IMG_0339.HEIC', 'IMG_0341.HEIC', 'IMG_0342.MOV', 'IMG_0343.MOV', 'IMG_0344.MOV', 'IMG_0345.JPG', 'IMG_0346.JPG', 'IMG_0348.MOV', 'IMG_0349.MOV', 'IMG_0350.HEIC', 'IMG_0351.HEIC', 'IMG_0352.HEIC', 'IMG_0353.HEIC', 'IMG_0354.HEIC', 'IMG_0355.HEIC', 'IMG_0356.HEIC', 'IMG_0357.HEIC', 'IMG_0358.HEIC', 'IMG_0359.MOV', 'IMG_0361.HEIC', 'IMG_0362.HEIC', 'IMG_0363.HEIC', 'IMG_0364.HEIC', 'IMG_0365.MOV', 'IMG_0366.HEIC', 'IMG_0367.HEIC', 'IMG_0368.HEIC', 'IMG_0369.HEIC', 'IMG_0370.HEIC', 'IMG_0371.JPG', 'IMG_0372.JPG', 'IMG_0373.JPG', 'IMG_0374.JPG', 'IMG_0375.MOV', 'IMG_0376.JPG', 'IMG_0377.MOV', 'IMG_0378.MOV', 'IMG_0379.MOV', 'IMG_0380.MOV', 'IMG_0381.MOV', 'IMG_0382.HEIC', 'IMG_0383.HEIC', 'IMG_0384.HEIC', 'IMG_0385.HEIC', 'IMG_0386.HEIC', 'IMG_0387.MOV', 'IMG_0388.MOV', 'IMG_0389.HEIC', 'IMG_0390.HEIC', 'IMG_0391.HEIC', 'IMG_0392.HEIC', 'IMG_0393.HEIC', 'IMG_0395.HEIC', 'IMG_0396.HEIC', 'IMG_0397.HEIC', 'IMG_0398.HEIC', 'IMG_0399.HEIC', 'IMG_0400.MOV', 'IMG_0401.HEIC', 'IMG_0402.HEIC', 'IMG_0403.HEIC', 'IMG_0404.HEIC', 'IMG_0405.MOV', 'IMG_0406.HEIC', 'IMG_0407.HEIC', 'IMG_0408.HEIC', 'IMG_0409.HEIC', 'IMG_0410.MOV', 'IMG_0411.MOV', 'IMG_0412.MOV', 'IMG_0413.MOV', 'IMG_0414.JPG', 'IMG_0415.MOV', 'IMG_0416.HEIC', 'IMG_0417.MOV', 'IMG_0418.MOV', 'IMG_0419.HEIC', 'IMG_0420.HEIC', 'IMG_0421.HEIC', 'IMG_0422.HEIC', 'IMG_0423.HEIC', 'IMG_0424.HEIC', 'IMG_0425.HEIC', 'IMG_0426.MOV', 'IMG_0427.MOV', 'IMG_0428.MOV', 'IMG_0429.MOV', 'IMG_0431.HEIC', 'IMG_0432.HEIC', 'IMG_0433.HEIC', 'IMG_0434.HEIC', 'IMG_0435.HEIC', 'IMG_0436.HEIC', 'IMG_0437.HEIC', 'IMG_0438.HEIC', 'IMG_0439.HEIC', 'IMG_0440.HEIC', 'IMG_0441.HEIC', 'IMG_0442.HEIC', 'IMG_0443.HEIC', 'IMG_0444.HEIC', 'IMG_0445.MOV', 'IMG_0446.MOV', 'IMG_0447.HEIC', 'IMG_0448.HEIC', 'IMG_0449.HEIC', 'IMG_0450.HEIC', 'IMG_0451.HEIC', 'IMG_0452.HEIC', 'IMG_0453.HEIC', 'IMG_0454.HEIC', 'IMG_0455.HEIC', 'IMG_0456.HEIC', 'IMG_0457.MOV', 'IMG_0458.HEIC', 'IMG_0459.HEIC', 'IMG_0460.HEIC', 'IMG_0461.HEIC', 'IMG_0462.HEIC', 'IMG_0463.HEIC', 'IMG_0464.HEIC', 'IMG_0465.HEIC', 'IMG_0466.HEIC', 'IMG_0467.HEIC', 'IMG_0469.HEIC', 'IMG_0470.HEIC', 'IMG_0471.MOV', 'IMG_0472.HEIC', 'IMG_0473.HEIC', 'IMG_0474.HEIC', 'IMG_0475.HEIC', 'IMG_0476.HEIC', 'IMG_0477.HEIC', 'IMG_0478.HEIC', 'IMG_0480.HEIC', 'IMG_0481.MOV', 'videos']
# Moved video file to ./images/videos: IMG_0323.MOV
# Moved video file to ./images/videos: IMG_0324.MOV
# Moved video file to ./images/videos: IMG_0326.MOV
# Moved video file to ./images/videos: IMG_0327.MOV
# Moved video file to ./images/videos: IMG_0328.MOV
# Moved video file to ./images/videos: IMG_0329.MOV
# Moved video file to ./images/videos: IMG_0330.MOV
# Moved video file to ./images/videos: IMG_0331.MOV
# Moved video file to ./images/videos: IMG_0332.MOV
# Converted IMG_0333(1).HEIC to ./images/IMG_0333(1).jpg
# Deleted original HEIC file: IMG_0333(1).HEIC
# Converted IMG_0333.HEIC to ./images/IMG_0333.jpg
# Deleted original HEIC file: IMG_0333.HEIC
# Converted IMG_0334.HEIC to ./images/IMG_0334.jpg
# Deleted original HEIC file: IMG_0334.HEIC
# Converted IMG_0335.HEIC to ./images/IMG_0335.jpg
# Deleted original HEIC file: IMG_0335.HEIC
# Converted IMG_0336.HEIC to ./images/IMG_0336.jpg
# Deleted original HEIC file: IMG_0336.HEIC
# Converted IMG_0337.HEIC to ./images/IMG_0337.jpg
# Deleted original HEIC file: IMG_0337.HEIC
# Moved video file to ./images/videos: IMG_0338.MOV
# Converted IMG_0339.HEIC to ./images/IMG_0339.jpg
# Deleted original HEIC file: IMG_0339.HEIC
# Converted IMG_0341.HEIC to ./images/IMG_0341.jpg
# Deleted original HEIC file: IMG_0341.HEIC
# Moved video file to ./images/videos: IMG_0342.MOV
# Moved video file to ./images/videos: IMG_0343.MOV
# Moved video file to ./images/videos: IMG_0344.MOV
# Converted IMG_0345.JPG to ./images/IMG_0345.jpg
# Converted IMG_0346.JPG to ./images/IMG_0346.jpg
# Moved video file to ./images/videos: IMG_0348.MOV
# Moved video file to ./images/videos: IMG_0349.MOV
# Converted IMG_0350.HEIC to ./images/IMG_0350.jpg
# Deleted original HEIC file: IMG_0350.HEIC
# Error converting IMG_0351.HEIC: Invalid input: No 'hvcC' box: No hvcC property in hvc1 type image
# Converted IMG_0352.HEIC to ./images/IMG_0352.jpg
# Deleted original HEIC file: IMG_0352.HEIC
# Converted IMG_0353.HEIC to ./images/IMG_0353.jpg
# Deleted original HEIC file: IMG_0353.HEIC
# Converted IMG_0354.HEIC to ./images/IMG_0354.jpg
# Deleted original HEIC file: IMG_0354.HEIC
# Converted IMG_0355.HEIC to ./images/IMG_0355.jpg
# Deleted original HEIC file: IMG_0355.HEIC
# Converted IMG_0356.HEIC to ./images/IMG_0356.jpg
# Deleted original HEIC file: IMG_0356.HEIC
# Converted IMG_0357.HEIC to ./images/IMG_0357.jpg
# Deleted original HEIC file: IMG_0357.HEIC
# Converted IMG_0358.HEIC to ./images/IMG_0358.jpg
# Deleted original HEIC file: IMG_0358.HEIC
# Moved video file to ./images/videos: IMG_0359.MOV
# Converted IMG_0361.HEIC to ./images/IMG_0361.jpg
# Deleted original HEIC file: IMG_0361.HEIC
# Converted IMG_0362.HEIC to ./images/IMG_0362.jpg
# Deleted original HEIC file: IMG_0362.HEIC
# Converted IMG_0363.HEIC to ./images/IMG_0363.jpg
# Deleted original HEIC file: IMG_0363.HEIC
# Converted IMG_0364.HEIC to ./images/IMG_0364.jpg
# Deleted original HEIC file: IMG_0364.HEIC
# Moved video file to ./images/videos: IMG_0365.MOV
# Converted IMG_0366.HEIC to ./images/IMG_0366.jpg
# Deleted original HEIC file: IMG_0366.HEIC
# Converted IMG_0367.HEIC to ./images/IMG_0367.jpg
# Deleted original HEIC file: IMG_0367.HEIC
# Converted IMG_0368.HEIC to ./images/IMG_0368.jpg
# Deleted original HEIC file: IMG_0368.HEIC
# Converted IMG_0369.HEIC to ./images/IMG_0369.jpg
# Deleted original HEIC file: IMG_0369.HEIC
# Converted IMG_0370.HEIC to ./images/IMG_0370.jpg
# Deleted original HEIC file: IMG_0370.HEIC
# Converted IMG_0371.JPG to ./images/IMG_0371.jpg
# Converted IMG_0372.JPG to ./images/IMG_0372.jpg
# Converted IMG_0373.JPG to ./images/IMG_0373.jpg
# Converted IMG_0374.JPG to ./images/IMG_0374.jpg
# Moved video file to ./images/videos: IMG_0375.MOV
# Converted IMG_0376.JPG to ./images/IMG_0376.jpg
# Moved video file to ./images/videos: IMG_0377.MOV
# Moved video file to ./images/videos: IMG_0378.MOV
# Moved video file to ./images/videos: IMG_0379.MOV
# Moved video file to ./images/videos: IMG_0380.MOV
# Moved video file to ./images/videos: IMG_0381.MOV
# Converted IMG_0382.HEIC to ./images/IMG_0382.jpg
# Deleted original HEIC file: IMG_0382.HEIC
# Converted IMG_0383.HEIC to ./images/IMG_0383.jpg
# Deleted original HEIC file: IMG_0383.HEIC
# Converted IMG_0384.HEIC to ./images/IMG_0384.jpg
# Deleted original HEIC file: IMG_0384.HEIC
# Converted IMG_0385.HEIC to ./images/IMG_0385.jpg
# Deleted original HEIC file: IMG_0385.HEIC
# Converted IMG_0386.HEIC to ./images/IMG_0386.jpg
# Deleted original HEIC file: IMG_0386.HEIC
# Moved video file to ./images/videos: IMG_0387.MOV
# Moved video file to ./images/videos: IMG_0388.MOV
# Converted IMG_0389.HEIC to ./images/IMG_0389.jpg
# Deleted original HEIC file: IMG_0389.HEIC
# Converted IMG_0390.HEIC to ./images/IMG_0390.jpg
# Deleted original HEIC file: IMG_0390.HEIC
# Converted IMG_0391.HEIC to ./images/IMG_0391.jpg
# Deleted original HEIC file: IMG_0391.HEIC
# Converted IMG_0392.HEIC to ./images/IMG_0392.jpg
# Deleted original HEIC file: IMG_0392.HEIC
# Converted IMG_0393.HEIC to ./images/IMG_0393.jpg
# Deleted original HEIC file: IMG_0393.HEIC
# Converted IMG_0395.HEIC to ./images/IMG_0395.jpg
# Deleted original HEIC file: IMG_0395.HEIC
# Converted IMG_0396.HEIC to ./images/IMG_0396.jpg
# Deleted original HEIC file: IMG_0396.HEIC
# Converted IMG_0397.HEIC to ./images/IMG_0397.jpg
# Deleted original HEIC file: IMG_0397.HEIC
# Converted IMG_0398.HEIC to ./images/IMG_0398.jpg
# Deleted original HEIC file: IMG_0398.HEIC
# Converted IMG_0399.HEIC to ./images/IMG_0399.jpg
# Deleted original HEIC file: IMG_0399.HEIC
# Moved video file to ./images/videos: IMG_0400.MOV
# Converted IMG_0401.HEIC to ./images/IMG_0401.jpg
# Deleted original HEIC file: IMG_0401.HEIC
# Converted IMG_0402.HEIC to ./images/IMG_0402.jpg
# Deleted original HEIC file: IMG_0402.HEIC
# Converted IMG_0403.HEIC to ./images/IMG_0403.jpg
# Deleted original HEIC file: IMG_0403.HEIC
# Converted IMG_0404.HEIC to ./images/IMG_0404.jpg
# Deleted original HEIC file: IMG_0404.HEIC
# Moved video file to ./images/videos: IMG_0405.MOV
# Converted IMG_0406.HEIC to ./images/IMG_0406.jpg
# Deleted original HEIC file: IMG_0406.HEIC
# Converted IMG_0407.HEIC to ./images/IMG_0407.jpg
# Deleted original HEIC file: IMG_0407.HEIC
# Converted IMG_0408.HEIC to ./images/IMG_0408.jpg
# Deleted original HEIC file: IMG_0408.HEIC
# Converted IMG_0409.HEIC to ./images/IMG_0409.jpg
# Deleted original HEIC file: IMG_0409.HEIC
# Moved video file to ./images/videos: IMG_0410.MOV
# Moved video file to ./images/videos: IMG_0411.MOV
# Moved video file to ./images/videos: IMG_0412.MOV
# Moved video file to ./images/videos: IMG_0413.MOV
# Converted IMG_0414.JPG to ./images/IMG_0414.jpg
# Moved video file to ./images/videos: IMG_0415.MOV
# Converted IMG_0416.HEIC to ./images/IMG_0416.jpg
# Deleted original HEIC file: IMG_0416.HEIC
# Moved video file to ./images/videos: IMG_0417.MOV
# Moved video file to ./images/videos: IMG_0418.MOV
# Converted IMG_0419.HEIC to ./images/IMG_0419.jpg
# Deleted original HEIC file: IMG_0419.HEIC
# Converted IMG_0420.HEIC to ./images/IMG_0420.jpg
# Deleted original HEIC file: IMG_0420.HEIC
# Converted IMG_0421.HEIC to ./images/IMG_0421.jpg
# Deleted original HEIC file: IMG_0421.HEIC
# Converted IMG_0422.HEIC to ./images/IMG_0422.jpg
# Deleted original HEIC file: IMG_0422.HEIC
# Converted IMG_0423.HEIC to ./images/IMG_0423.jpg
# Deleted original HEIC file: IMG_0423.HEIC
# Converted IMG_0424.HEIC to ./images/IMG_0424.jpg
# Deleted original HEIC file: IMG_0424.HEIC
# Converted IMG_0425.HEIC to ./images/IMG_0425.jpg
# Deleted original HEIC file: IMG_0425.HEIC
# Moved video file to ./images/videos: IMG_0426.MOV
# Moved video file to ./images/videos: IMG_0427.MOV
# Moved video file to ./images/videos: IMG_0428.MOV
# Moved video file to ./images/videos: IMG_0429.MOV
# Converted IMG_0431.HEIC to ./images/IMG_0431.jpg
# Deleted original HEIC file: IMG_0431.HEIC
# Converted IMG_0432.HEIC to ./images/IMG_0432.jpg
# Deleted original HEIC file: IMG_0432.HEIC
# Converted IMG_0433.HEIC to ./images/IMG_0433.jpg
# Deleted original HEIC file: IMG_0433.HEIC
# Converted IMG_0434.HEIC to ./images/IMG_0434.jpg
# Deleted original HEIC file: IMG_0434.HEIC
# Converted IMG_0435.HEIC to ./images/IMG_0435.jpg
# Deleted original HEIC file: IMG_0435.HEIC
# Converted IMG_0436.HEIC to ./images/IMG_0436.jpg
# Deleted original HEIC file: IMG_0436.HEIC
# Converted IMG_0437.HEIC to ./images/IMG_0437.jpg
# Deleted original HEIC file: IMG_0437.HEIC
# Converted IMG_0438.HEIC to ./images/IMG_0438.jpg
# Deleted original HEIC file: IMG_0438.HEIC
# Converted IMG_0439.HEIC to ./images/IMG_0439.jpg
# Deleted original HEIC file: IMG_0439.HEIC
# Converted IMG_0440.HEIC to ./images/IMG_0440.jpg
# Deleted original HEIC file: IMG_0440.HEIC
# Converted IMG_0441.HEIC to ./images/IMG_0441.jpg
# Deleted original HEIC file: IMG_0441.HEIC
# Converted IMG_0442.HEIC to ./images/IMG_0442.jpg
# Deleted original HEIC file: IMG_0442.HEIC
# Converted IMG_0443.HEIC to ./images/IMG_0443.jpg
# Deleted original HEIC file: IMG_0443.HEIC
# Converted IMG_0444.HEIC to ./images/IMG_0444.jpg
# Deleted original HEIC file: IMG_0444.HEIC
# Moved video file to ./images/videos: IMG_0445.MOV
# Moved video file to ./images/videos: IMG_0446.MOV
# Converted IMG_0447.HEIC to ./images/IMG_0447.jpg
# Deleted original HEIC file: IMG_0447.HEIC
# Converted IMG_0448.HEIC to ./images/IMG_0448.jpg
# Deleted original HEIC file: IMG_0448.HEIC
# Converted IMG_0449.HEIC to ./images/IMG_0449.jpg
# Deleted original HEIC file: IMG_0449.HEIC
# Converted IMG_0450.HEIC to ./images/IMG_0450.jpg
# Deleted original HEIC file: IMG_0450.HEIC
# Converted IMG_0451.HEIC to ./images/IMG_0451.jpg
# Deleted original HEIC file: IMG_0451.HEIC
# Converted IMG_0452.HEIC to ./images/IMG_0452.jpg
# Deleted original HEIC file: IMG_0452.HEIC
# Converted IMG_0453.HEIC to ./images/IMG_0453.jpg
# Deleted original HEIC file: IMG_0453.HEIC
# Converted IMG_0454.HEIC to ./images/IMG_0454.jpg
# Deleted original HEIC file: IMG_0454.HEIC
# Converted IMG_0455.HEIC to ./images/IMG_0455.jpg
# Deleted original HEIC file: IMG_0455.HEIC
# Converted IMG_0456.HEIC to ./images/IMG_0456.jpg
# Deleted original HEIC file: IMG_0456.HEIC
# Moved video file to ./images/videos: IMG_0457.MOV
# Converted IMG_0458.HEIC to ./images/IMG_0458.jpg
# Deleted original HEIC file: IMG_0458.HEIC
# Converted IMG_0459.HEIC to ./images/IMG_0459.jpg
# Deleted original HEIC file: IMG_0459.HEIC
# Converted IMG_0460.HEIC to ./images/IMG_0460.jpg
# Deleted original HEIC file: IMG_0460.HEIC
# Converted IMG_0461.HEIC to ./images/IMG_0461.jpg
# Deleted original HEIC file: IMG_0461.HEIC
# Converted IMG_0462.HEIC to ./images/IMG_0462.jpg
# Deleted original HEIC file: IMG_0462.HEIC
# Converted IMG_0463.HEIC to ./images/IMG_0463.jpg
# Deleted original HEIC file: IMG_0463.HEIC
# Converted IMG_0464.HEIC to ./images/IMG_0464.jpg
# Deleted original HEIC file: IMG_0464.HEIC
# Converted IMG_0465.HEIC to ./images/IMG_0465.jpg
# Deleted original HEIC file: IMG_0465.HEIC
# Converted IMG_0466.HEIC to ./images/IMG_0466.jpg
# Deleted original HEIC file: IMG_0466.HEIC
# Converted IMG_0467.HEIC to ./images/IMG_0467.jpg
# Deleted original HEIC file: IMG_0467.HEIC
# Converted IMG_0469.HEIC to ./images/IMG_0469.jpg
# Deleted original HEIC file: IMG_0469.HEIC
# Converted IMG_0470.HEIC to ./images/IMG_0470.jpg
# Deleted original HEIC file: IMG_0470.HEIC
# Moved video file to ./images/videos: IMG_0471.MOV
# Converted IMG_0472.HEIC to ./images/IMG_0472.jpg
# Deleted original HEIC file: IMG_0472.HEIC
# Converted IMG_0473.HEIC to ./images/IMG_0473.jpg
# Deleted original HEIC file: IMG_0473.HEIC
# Converted IMG_0474.HEIC to ./images/IMG_0474.jpg
# Deleted original HEIC file: IMG_0474.HEIC
# Converted IMG_0475.HEIC to ./images/IMG_0475.jpg
# Deleted original HEIC file: IMG_0475.HEIC
# Converted IMG_0476.HEIC to ./images/IMG_0476.jpg
# Deleted original HEIC file: IMG_0476.HEIC
# Converted IMG_0477.HEIC to ./images/IMG_0477.jpg
# Deleted original HEIC file: IMG_0477.HEIC
# Converted IMG_0478.HEIC to ./images/IMG_0478.jpg
# Deleted original HEIC file: IMG_0478.HEIC
# Converted IMG_0480.HEIC to ./images/IMG_0480.jpg
# Deleted original HEIC file: IMG_0480.HEIC
# Moved video file to ./images/videos: IMG_0481.MOV

# %% [markdown]
# # Feature Extraction Using VGG16

# %%
def extract_features(image_path):
    # Load VGG16 model without the top layer (only the feature extraction part)
    base_model = VGG16(weights='imagenet', include_top=False)
    model = Model(inputs=base_model.input, outputs=base_model.output)

    # Load and preprocess the image
    img = Image.open(image_path)
    img = img.resize((224, 224))  # Resize to VGG16 input size
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    # Extract features
    features = model.predict(img_array)
    features = features.flatten()  # Flatten to 1D array
    return features

# %% [markdown]
# # Identify Duplicates

# %%
def identify_duplicates(image_folder, dupes_folder, best_folder, threshold=0.5):
    image_features = defaultdict(list)
    
    # Extract features for all images
    for filename in os.listdir(image_folder):
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(image_folder, filename)
            features = extract_features(image_path)
            image_features[filename] = features

    # Create the dupes and best folders if they don't exist
    os.makedirs(dupes_folder, exist_ok=True)
    os.makedirs(best_folder, exist_ok=True)

    kept_images = []
    checked = set()

    for img1, features1 in image_features.items():
        if img1 in checked:
            continue
        kept_images.append(img1)
        checked.add(img1)

        for img2, features2 in image_features.items():
            if img1 != img2 and img2 not in checked:
                # Calculate similarity using cosine similarity
                similarity = np.dot(features1, features2) / (np.linalg.norm(features1) * np.linalg.norm(features2))
                print(f"Comparing {img1} and {img2}: Similarity = {similarity:.4f}")  # Debugging output
                
                if similarity > threshold:
                    img2_path = os.path.join(image_folder, img2)
                    if os.path.exists(img2_path):  # Check if the image exists before moving
                        shutil.move(img2_path, os.path.join(dupes_folder, img2))
                        print(f"Moved duplicate image to dupes folder: {img2}")

    # Move kept images to the best folder
    for kept_image in kept_images:
        kept_image_path = os.path.join(image_folder, kept_image)
        if os.path.exists(kept_image_path):  # Check if the image exists before moving
            shutil.move(kept_image_path, os.path.join(best_folder, kept_image))
            print(f"Moved kept image to best folder: {kept_image}")

# %% [markdown]
# # Run Duplicate Identification

# %%
# Define output folders
dupes_folder = './images/dupes/'  # Folder to save duplicate images
best_folder = './images/best/'      # Folder to save best images

# Identify duplicates
identify_duplicates(image_folder, dupes_folder, best_folder)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000201C59596C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000201C5959DA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Comparing IMG_0333(1).jpg and IMG_0333.jpg: Similarity = 1.0000
# Moved duplicate image to dupes folder: IMG_0333.jpg
# Comparing IMG_0333(1).jpg and IMG_0334.jpg: Similarity = 0.0724
# Comparing IMG_0333(1).jpg and IMG_0335.jpg: Similarity = 0.0792
# Comparing IMG_0333(1).jpg and IMG_0336.jpg: Similarity = 0.0454
# Comparing IMG_0333(1).jpg and IMG_0337.jpg: Similarity = 0.0561
# Comparing IMG_0333(1).jpg and IMG_0339.jpg: Similarity = 0.0315
# Comparing IMG_0333(1).jpg and IMG_0341.jpg: Similarity = 0.0353
# Comparing IMG_0333(1).jpg and IMG_0345.JPG: Similarity = 0.0613
# Comparing IMG_0333(1).jpg and IMG_0346.JPG: Similarity = 0.0675
# Comparing IMG_0333(1).jpg and IMG_0350.jpg: Similarity = 0.0336
# Comparing IMG_0333(1).jpg and IMG_0352.jpg: Similarity = 0.0398
# Comparing IMG_0333(1).jpg and IMG_0353.jpg: Similarity = 0.0289
# Comparing IMG_0333(1).jpg and IMG_0354.jpg: Similarity = 0.0293
# Comparing IMG_0333(1).jpg and IMG_0355.jpg: Similarity = 0.0387
# Comparing IMG_0333(1).jpg and IMG_0356.jpg: Similarity = 0.0280
# Comparing IMG_0333(1).jpg and IMG_0357.jpg: Similarity = 0.0296
# Comparing IMG_0333(1).jpg and IMG_0358.jpg: Similarity = 0.0346
# Comparing IMG_0333(1).jpg and IMG_0361.jpg: Similarity = 0.0122
# Comparing IMG_0333(1).jpg and IMG_0362.jpg: Similarity = 0.0134
# Comparing IMG_0333(1).jpg and IMG_0363.jpg: Similarity = 0.0160
# Comparing IMG_0333(1).jpg and IMG_0364.jpg: Similarity = 0.0187
# Comparing IMG_0333(1).jpg and IMG_0366.jpg: Similarity = 0.0422
# Comparing IMG_0333(1).jpg and IMG_0367.jpg: Similarity = 0.0370
# Comparing IMG_0333(1).jpg and IMG_0368.jpg: Similarity = 0.0431
# Comparing IMG_0333(1).jpg and IMG_0369.jpg: Similarity = 0.0281
# Comparing IMG_0333(1).jpg and IMG_0370.jpg: Similarity = 0.0270
# Comparing IMG_0333(1).jpg and IMG_0371.JPG: Similarity = 0.0342
# Comparing IMG_0333(1).jpg and IMG_0372.JPG: Similarity = 0.0421
# Comparing IMG_0333(1).jpg and IMG_0373.JPG: Similarity = 0.0398
# Comparing IMG_0333(1).jpg and IMG_0374.JPG: Similarity = 0.0440
# Comparing IMG_0333(1).jpg and IMG_0376.JPG: Similarity = 0.0167
# Comparing IMG_0333(1).jpg and IMG_0382.jpg: Similarity = 0.0975
# Comparing IMG_0333(1).jpg and IMG_0383.jpg: Similarity = 0.1046
# Comparing IMG_0333(1).jpg and IMG_0384.jpg: Similarity = 0.0960
# Comparing IMG_0333(1).jpg and IMG_0385.jpg: Similarity = 0.0976
# Comparing IMG_0333(1).jpg and IMG_0386.jpg: Similarity = 0.1492
# Comparing IMG_0333(1).jpg and IMG_0389.jpg: Similarity = 0.1404
# Comparing IMG_0333(1).jpg and IMG_0390.jpg: Similarity = 0.0793
# Comparing IMG_0333(1).jpg and IMG_0391.jpg: Similarity = 0.0824
# Comparing IMG_0333(1).jpg and IMG_0392.jpg: Similarity = 0.1392
# Comparing IMG_0333(1).jpg and IMG_0393.jpg: Similarity = 0.1418
# Comparing IMG_0333(1).jpg and IMG_0395.jpg: Similarity = 0.0837
# Comparing IMG_0333(1).jpg and IMG_0396.jpg: Similarity = 0.0685
# Comparing IMG_0333(1).jpg and IMG_0397.jpg: Similarity = 0.0589
# Comparing IMG_0333(1).jpg and IMG_0398.jpg: Similarity = 0.0692
# Comparing IMG_0333(1).jpg and IMG_0399.jpg: Similarity = 0.0818
# Comparing IMG_0333(1).jpg and IMG_0401.jpg: Similarity = 0.0681
# Comparing IMG_0333(1).jpg and IMG_0402.jpg: Similarity = 0.0552
# Comparing IMG_0333(1).jpg and IMG_0403.jpg: Similarity = 0.0561
# Comparing IMG_0333(1).jpg and IMG_0404.jpg: Similarity = 0.0632
# Comparing IMG_0333(1).jpg and IMG_0406.jpg: Similarity = 0.0670
# Comparing IMG_0333(1).jpg and IMG_0407.jpg: Similarity = 0.0725
# Comparing IMG_0333(1).jpg and IMG_0408.jpg: Similarity = 0.0339
# Comparing IMG_0333(1).jpg and IMG_0409.jpg: Similarity = 0.0206
# Comparing IMG_0333(1).jpg and IMG_0414.JPG: Similarity = 0.0321
# Comparing IMG_0333(1).jpg and IMG_0416.jpg: Similarity = 0.0599
# Comparing IMG_0333(1).jpg and IMG_0419.jpg: Similarity = 0.0342
# Comparing IMG_0333(1).jpg and IMG_0420.jpg: Similarity = 0.0152
# Comparing IMG_0333(1).jpg and IMG_0421.jpg: Similarity = 0.0187
# Comparing IMG_0333(1).jpg and IMG_0422.jpg: Similarity = 0.0277
# Comparing IMG_0333(1).jpg and IMG_0423.jpg: Similarity = 0.0286
# Comparing IMG_0333(1).jpg and IMG_0424.jpg: Similarity = 0.0399
# Comparing IMG_0333(1).jpg and IMG_0425.jpg: Similarity = 0.0436
# Comparing IMG_0333(1).jpg and IMG_0431.jpg: Similarity = 0.0577
# Comparing IMG_0333(1).jpg and IMG_0432.jpg: Similarity = 0.0629
# Comparing IMG_0333(1).jpg and IMG_0433.jpg: Similarity = 0.0710
# Comparing IMG_0333(1).jpg and IMG_0434.jpg: Similarity = 0.0731
# Comparing IMG_0333(1).jpg and IMG_0435.jpg: Similarity = 0.0625
# Comparing IMG_0333(1).jpg and IMG_0436.jpg: Similarity = 0.0596
# Comparing IMG_0333(1).jpg and IMG_0437.jpg: Similarity = 0.0596
# Comparing IMG_0333(1).jpg and IMG_0438.jpg: Similarity = 0.1256
# Comparing IMG_0333(1).jpg and IMG_0439.jpg: Similarity = 0.0165
# Comparing IMG_0333(1).jpg and IMG_0440.jpg: Similarity = 0.0715
# Comparing IMG_0333(1).jpg and IMG_0441.jpg: Similarity = 0.0771
# Comparing IMG_0333(1).jpg and IMG_0442.jpg: Similarity = 0.0916
# Comparing IMG_0333(1).jpg and IMG_0443.jpg: Similarity = 0.0818
# Comparing IMG_0333(1).jpg and IMG_0444.jpg: Similarity = 0.0784
# Comparing IMG_0333(1).jpg and IMG_0447.jpg: Similarity = 0.0480
# Comparing IMG_0333(1).jpg and IMG_0448.jpg: Similarity = 0.0413
# Comparing IMG_0333(1).jpg and IMG_0449.jpg: Similarity = 0.0325
# Comparing IMG_0333(1).jpg and IMG_0450.jpg: Similarity = 0.0685
# Comparing IMG_0333(1).jpg and IMG_0451.jpg: Similarity = 0.0618
# Comparing IMG_0333(1).jpg and IMG_0452.jpg: Similarity = 0.1650
# Comparing IMG_0333(1).jpg and IMG_0453.jpg: Similarity = 0.0505
# Comparing IMG_0333(1).jpg and IMG_0454.jpg: Similarity = 0.0535
# Comparing IMG_0333(1).jpg and IMG_0455.jpg: Similarity = 0.0527
# Comparing IMG_0333(1).jpg and IMG_0456.jpg: Similarity = 0.1534
# Comparing IMG_0333(1).jpg and IMG_0458.jpg: Similarity = 0.0576
# Comparing IMG_0333(1).jpg and IMG_0459.jpg: Similarity = 0.0541
# Comparing IMG_0333(1).jpg and IMG_0460.jpg: Similarity = 0.0617
# Comparing IMG_0333(1).jpg and IMG_0461.jpg: Similarity = 0.0639
# Comparing IMG_0333(1).jpg and IMG_0462.jpg: Similarity = 0.1396
# Comparing IMG_0333(1).jpg and IMG_0463.jpg: Similarity = 0.1403
# Comparing IMG_0333(1).jpg and IMG_0464.jpg: Similarity = 0.0879
# Comparing IMG_0333(1).jpg and IMG_0465.jpg: Similarity = 0.0996
# Comparing IMG_0333(1).jpg and IMG_0466.jpg: Similarity = 0.0161
# Comparing IMG_0333(1).jpg and IMG_0467.jpg: Similarity = 0.0164
# Comparing IMG_0333(1).jpg and IMG_0469.jpg: Similarity = 0.0377
# Comparing IMG_0333(1).jpg and IMG_0470.jpg: Similarity = 0.0180
# Comparing IMG_0333(1).jpg and IMG_0472.jpg: Similarity = 0.0353
# Comparing IMG_0333(1).jpg and IMG_0473.jpg: Similarity = 0.1734
# Comparing IMG_0333(1).jpg and IMG_0474.jpg: Similarity = 0.0106
# Comparing IMG_0333(1).jpg and IMG_0475.jpg: Similarity = 0.0760
# Comparing IMG_0333(1).jpg and IMG_0476.jpg: Similarity = 0.1257
# Comparing IMG_0333(1).jpg and IMG_0477.jpg: Similarity = 0.1069
# Comparing IMG_0333(1).jpg and IMG_0478.jpg: Similarity = 0.0984
# Comparing IMG_0333(1).jpg and IMG_0480.jpg: Similarity = 0.0914
# Comparing IMG_0333.jpg and IMG_0334.jpg: Similarity = 0.0724
# Comparing IMG_0333.jpg and IMG_0335.jpg: Similarity = 0.0792
# Comparing IMG_0333.jpg and IMG_0336.jpg: Similarity = 0.0454
# Comparing IMG_0333.jpg and IMG_0337.jpg: Similarity = 0.0561
# Comparing IMG_0333.jpg and IMG_0339.jpg: Similarity = 0.0315
# Comparing IMG_0333.jpg and IMG_0341.jpg: Similarity = 0.0353
# Comparing IMG_0333.jpg and IMG_0345.JPG: Similarity = 0.0613
# Comparing IMG_0333.jpg and IMG_0346.JPG: Similarity = 0.0675
# Comparing IMG_0333.jpg and IMG_0350.jpg: Similarity = 0.0336
# Comparing IMG_0333.jpg and IMG_0352.jpg: Similarity = 0.0398
# Comparing IMG_0333.jpg and IMG_0353.jpg: Similarity = 0.0289
# Comparing IMG_0333.jpg and IMG_0354.jpg: Similarity = 0.0293
# Comparing IMG_0333.jpg and IMG_0355.jpg: Similarity = 0.0387
# Comparing IMG_0333.jpg and IMG_0356.jpg: Similarity = 0.0280
# Comparing IMG_0333.jpg and IMG_0357.jpg: Similarity = 0.0296
# Comparing IMG_0333.jpg and IMG_0358.jpg: Similarity = 0.0346
# Comparing IMG_0333.jpg and IMG_0361.jpg: Similarity = 0.0122
# Comparing IMG_0333.jpg and IMG_0362.jpg: Similarity = 0.0134
# Comparing IMG_0333.jpg and IMG_0363.jpg: Similarity = 0.0160
# Comparing IMG_0333.jpg and IMG_0364.jpg: Similarity = 0.0187
# Comparing IMG_0333.jpg and IMG_0366.jpg: Similarity = 0.0422
# Comparing IMG_0333.jpg and IMG_0367.jpg: Similarity = 0.0370
# Comparing IMG_0333.jpg and IMG_0368.jpg: Similarity = 0.0431
# Comparing IMG_0333.jpg and IMG_0369.jpg: Similarity = 0.0281
# Comparing IMG_0333.jpg and IMG_0370.jpg: Similarity = 0.0270
# Comparing IMG_0333.jpg and IMG_0371.JPG: Similarity = 0.0342
# Comparing IMG_0333.jpg and IMG_0372.JPG: Similarity = 0.0421
# Comparing IMG_0333.jpg and IMG_0373.JPG: Similarity = 0.0398
# Comparing IMG_0333.jpg and IMG_0374.JPG: Similarity = 0.0440
# Comparing IMG_0333.jpg and IMG_0376.JPG: Similarity = 0.0167
# Comparing IMG_0333.jpg and IMG_0382.jpg: Similarity = 0.0975
# Comparing IMG_0333.jpg and IMG_0383.jpg: Similarity = 0.1046
# Comparing IMG_0333.jpg and IMG_0384.jpg: Similarity = 0.0960
# Comparing IMG_0333.jpg and IMG_0385.jpg: Similarity = 0.0976
# Comparing IMG_0333.jpg and IMG_0386.jpg: Similarity = 0.1492
# Comparing IMG_0333.jpg and IMG_0389.jpg: Similarity = 0.1404
# Comparing IMG_0333.jpg and IMG_0390.jpg: Similarity = 0.0793
# Comparing IMG_0333.jpg and IMG_0391.jpg: Similarity = 0.0824
# Comparing IMG_0333.jpg and IMG_0392.jpg: Similarity = 0.1392
# Comparing IMG_0333.jpg and IMG_0393.jpg: Similarity = 0.1418
# Comparing IMG_0333.jpg and IMG_0395.jpg: Similarity = 0.0837
# Comparing IMG_0333.jpg and IMG_0396.jpg: Similarity = 0.0685
# Comparing IMG_0333.jpg and IMG_0397.jpg: Similarity = 0.0589
# Comparing IMG_0333.jpg and IMG_0398.jpg: Similarity = 0.0692
# Comparing IMG_0333.jpg and IMG_0399.jpg: Similarity = 0.0818
# Comparing IMG_0333.jpg and IMG_0401.jpg: Similarity = 0.0681
# Comparing IMG_0333.jpg and IMG_0402.jpg: Similarity = 0.0552
# Comparing IMG_0333.jpg and IMG_0403.jpg: Similarity = 0.0561
# Comparing IMG_0333.jpg and IMG_0404.jpg: Similarity = 0.0632
# Comparing IMG_0333.jpg and IMG_0406.jpg: Similarity = 0.0670
# Comparing IMG_0333.jpg and IMG_0407.jpg: Similarity = 0.0725
# Comparing IMG_0333.jpg and IMG_0408.jpg: Similarity = 0.0339
# Comparing IMG_0333.jpg and IMG_0409.jpg: Similarity = 0.0206
# Comparing IMG_0333.jpg and IMG_0414.JPG: Similarity = 0.0321
# Comparing IMG_0333.jpg and IMG_0416.jpg: Similarity = 0.0599
# Comparing IMG_0333.jpg and IMG_0419.jpg: Similarity = 0.0342
# Comparing IMG_0333.jpg and IMG_0420.jpg: Similarity = 0.0152
# Comparing IMG_0333.jpg and IMG_0421.jpg: Similarity = 0.0187
# Comparing IMG_0333.jpg and IMG_0422.jpg: Similarity = 0.0277
# Comparing IMG_0333.jpg and IMG_0423.jpg: Similarity = 0.0286
# Comparing IMG_0333.jpg and IMG_0424.jpg: Similarity = 0.0399
# Comparing IMG_0333.jpg and IMG_0425.jpg: Similarity = 0.0436
# Comparing IMG_0333.jpg and IMG_0431.jpg: Similarity = 0.0577
# Comparing IMG_0333.jpg and IMG_0432.jpg: Similarity = 0.0629
# Comparing IMG_0333.jpg and IMG_0433.jpg: Similarity = 0.0710
# Comparing IMG_0333.jpg and IMG_0434.jpg: Similarity = 0.0731
# Comparing IMG_0333.jpg and IMG_0435.jpg: Similarity = 0.0625
# Comparing IMG_0333.jpg and IMG_0436.jpg: Similarity = 0.0596
# Comparing IMG_0333.jpg and IMG_0437.jpg: Similarity = 0.0596
# Comparing IMG_0333.jpg and IMG_0438.jpg: Similarity = 0.1256
# Comparing IMG_0333.jpg and IMG_0439.jpg: Similarity = 0.0165
# Comparing IMG_0333.jpg and IMG_0440.jpg: Similarity = 0.0715
# Comparing IMG_0333.jpg and IMG_0441.jpg: Similarity = 0.0771
# Comparing IMG_0333.jpg and IMG_0442.jpg: Similarity = 0.0916
# Comparing IMG_0333.jpg and IMG_0443.jpg: Similarity = 0.0818
# Comparing IMG_0333.jpg and IMG_0444.jpg: Similarity = 0.0784
# Comparing IMG_0333.jpg and IMG_0447.jpg: Similarity = 0.0480
# Comparing IMG_0333.jpg and IMG_0448.jpg: Similarity = 0.0413
# Comparing IMG_0333.jpg and IMG_0449.jpg: Similarity = 0.0325
# Comparing IMG_0333.jpg and IMG_0450.jpg: Similarity = 0.0685
# Comparing IMG_0333.jpg and IMG_0451.jpg: Similarity = 0.0618
# Comparing IMG_0333.jpg and IMG_0452.jpg: Similarity = 0.1650
# Comparing IMG_0333.jpg and IMG_0453.jpg: Similarity = 0.0505
# Comparing IMG_0333.jpg and IMG_0454.jpg: Similarity = 0.0535
# Comparing IMG_0333.jpg and IMG_0455.jpg: Similarity = 0.0527
# Comparing IMG_0333.jpg and IMG_0456.jpg: Similarity = 0.1534
# Comparing IMG_0333.jpg and IMG_0458.jpg: Similarity = 0.0576
# Comparing IMG_0333.jpg and IMG_0459.jpg: Similarity = 0.0541
# Comparing IMG_0333.jpg and IMG_0460.jpg: Similarity = 0.0617
# Comparing IMG_0333.jpg and IMG_0461.jpg: Similarity = 0.0639
# Comparing IMG_0333.jpg and IMG_0462.jpg: Similarity = 0.1396
# Comparing IMG_0333.jpg and IMG_0463.jpg: Similarity = 0.1403
# Comparing IMG_0333.jpg and IMG_0464.jpg: Similarity = 0.0879
# Comparing IMG_0333.jpg and IMG_0465.jpg: Similarity = 0.0996
# Comparing IMG_0333.jpg and IMG_0466.jpg: Similarity = 0.0161
# Comparing IMG_0333.jpg and IMG_0467.jpg: Similarity = 0.0164
# Comparing IMG_0333.jpg and IMG_0469.jpg: Similarity = 0.0377
# Comparing IMG_0333.jpg and IMG_0470.jpg: Similarity = 0.0180
# Comparing IMG_0333.jpg and IMG_0472.jpg: Similarity = 0.0353
# Comparing IMG_0333.jpg and IMG_0473.jpg: Similarity = 0.1734
# Comparing IMG_0333.jpg and IMG_0474.jpg: Similarity = 0.0106
# Comparing IMG_0333.jpg and IMG_0475.jpg: Similarity = 0.0760
# Comparing IMG_0333.jpg and IMG_0476.jpg: Similarity = 0.1257
# Comparing IMG_0333.jpg and IMG_0477.jpg: Similarity = 0.1069
# Comparing IMG_0333.jpg and IMG_0478.jpg: Similarity = 0.0984
# Comparing IMG_0333.jpg and IMG_0480.jpg: Similarity = 0.0914
# Comparing IMG_0334.jpg and IMG_0335.jpg: Similarity = 0.9104
# Moved duplicate image to dupes folder: IMG_0335.jpg
# Comparing IMG_0334.jpg and IMG_0336.jpg: Similarity = 0.5913
# Moved duplicate image to dupes folder: IMG_0336.jpg
# Comparing IMG_0334.jpg and IMG_0337.jpg: Similarity = 0.6016
# Moved duplicate image to dupes folder: IMG_0337.jpg
# Comparing IMG_0334.jpg and IMG_0339.jpg: Similarity = 0.0539
# Comparing IMG_0334.jpg and IMG_0341.jpg: Similarity = 0.1290
# Comparing IMG_0334.jpg and IMG_0345.JPG: Similarity = 0.0879
# Comparing IMG_0334.jpg and IMG_0346.JPG: Similarity = 0.0761
# Comparing IMG_0334.jpg and IMG_0350.jpg: Similarity = 0.1197
# Comparing IMG_0334.jpg and IMG_0352.jpg: Similarity = 0.1591
# Comparing IMG_0334.jpg and IMG_0353.jpg: Similarity = 0.0923
# Comparing IMG_0334.jpg and IMG_0354.jpg: Similarity = 0.0985
# Comparing IMG_0334.jpg and IMG_0355.jpg: Similarity = 0.1247
# Comparing IMG_0334.jpg and IMG_0356.jpg: Similarity = 0.1011
# Comparing IMG_0334.jpg and IMG_0357.jpg: Similarity = 0.1044
# Comparing IMG_0334.jpg and IMG_0358.jpg: Similarity = 0.1037
# Comparing IMG_0334.jpg and IMG_0361.jpg: Similarity = 0.1433
# Comparing IMG_0334.jpg and IMG_0362.jpg: Similarity = 0.1156
# Comparing IMG_0334.jpg and IMG_0363.jpg: Similarity = 0.1009
# Comparing IMG_0334.jpg and IMG_0364.jpg: Similarity = 0.1243
# Comparing IMG_0334.jpg and IMG_0366.jpg: Similarity = 0.0708
# Comparing IMG_0334.jpg and IMG_0367.jpg: Similarity = 0.0749
# Comparing IMG_0334.jpg and IMG_0368.jpg: Similarity = 0.0827
# Comparing IMG_0334.jpg and IMG_0369.jpg: Similarity = 0.0946
# Comparing IMG_0334.jpg and IMG_0370.jpg: Similarity = 0.0935
# Comparing IMG_0334.jpg and IMG_0371.JPG: Similarity = 0.1017
# Comparing IMG_0334.jpg and IMG_0372.JPG: Similarity = 0.0963
# Comparing IMG_0334.jpg and IMG_0373.JPG: Similarity = 0.0877
# Comparing IMG_0334.jpg and IMG_0374.JPG: Similarity = 0.1084
# Comparing IMG_0334.jpg and IMG_0376.JPG: Similarity = 0.0884
# Comparing IMG_0334.jpg and IMG_0382.jpg: Similarity = 0.2143
# Comparing IMG_0334.jpg and IMG_0383.jpg: Similarity = 0.2142
# Comparing IMG_0334.jpg and IMG_0384.jpg: Similarity = 0.1952
# Comparing IMG_0334.jpg and IMG_0385.jpg: Similarity = 0.1791
# Comparing IMG_0334.jpg and IMG_0386.jpg: Similarity = 0.0849
# Comparing IMG_0334.jpg and IMG_0389.jpg: Similarity = 0.1328
# Comparing IMG_0334.jpg and IMG_0390.jpg: Similarity = 0.2091
# Comparing IMG_0334.jpg and IMG_0391.jpg: Similarity = 0.1721
# Comparing IMG_0334.jpg and IMG_0392.jpg: Similarity = 0.0789
# Comparing IMG_0334.jpg and IMG_0393.jpg: Similarity = 0.1128
# Comparing IMG_0334.jpg and IMG_0395.jpg: Similarity = 0.1575
# Comparing IMG_0334.jpg and IMG_0396.jpg: Similarity = 0.1461
# Comparing IMG_0334.jpg and IMG_0397.jpg: Similarity = 0.1337
# Comparing IMG_0334.jpg and IMG_0398.jpg: Similarity = 0.1686
# Comparing IMG_0334.jpg and IMG_0399.jpg: Similarity = 0.1845
# Comparing IMG_0334.jpg and IMG_0401.jpg: Similarity = 0.2292
# Comparing IMG_0334.jpg and IMG_0402.jpg: Similarity = 0.2450
# Comparing IMG_0334.jpg and IMG_0403.jpg: Similarity = 0.2403
# Comparing IMG_0334.jpg and IMG_0404.jpg: Similarity = 0.2336
# Comparing IMG_0334.jpg and IMG_0406.jpg: Similarity = 0.1555
# Comparing IMG_0334.jpg and IMG_0407.jpg: Similarity = 0.1515
# Comparing IMG_0334.jpg and IMG_0408.jpg: Similarity = 0.0647
# Comparing IMG_0334.jpg and IMG_0409.jpg: Similarity = 0.0811
# Comparing IMG_0334.jpg and IMG_0414.JPG: Similarity = 0.0647
# Comparing IMG_0334.jpg and IMG_0416.jpg: Similarity = 0.1600
# Comparing IMG_0334.jpg and IMG_0419.jpg: Similarity = 0.0653
# Comparing IMG_0334.jpg and IMG_0420.jpg: Similarity = 0.0677
# Comparing IMG_0334.jpg and IMG_0421.jpg: Similarity = 0.0709
# Comparing IMG_0334.jpg and IMG_0422.jpg: Similarity = 0.0449
# Comparing IMG_0334.jpg and IMG_0423.jpg: Similarity = 0.0562
# Comparing IMG_0334.jpg and IMG_0424.jpg: Similarity = 0.1307
# Comparing IMG_0334.jpg and IMG_0425.jpg: Similarity = 0.1353
# Comparing IMG_0334.jpg and IMG_0431.jpg: Similarity = 0.1559
# Comparing IMG_0334.jpg and IMG_0432.jpg: Similarity = 0.1522
# Comparing IMG_0334.jpg and IMG_0433.jpg: Similarity = 0.1381
# Comparing IMG_0334.jpg and IMG_0434.jpg: Similarity = 0.1413
# Comparing IMG_0334.jpg and IMG_0435.jpg: Similarity = 0.1510
# Comparing IMG_0334.jpg and IMG_0436.jpg: Similarity = 0.1444
# Comparing IMG_0334.jpg and IMG_0437.jpg: Similarity = 0.1552
# Comparing IMG_0334.jpg and IMG_0438.jpg: Similarity = 0.0876
# Comparing IMG_0334.jpg and IMG_0439.jpg: Similarity = 0.0557
# Comparing IMG_0334.jpg and IMG_0440.jpg: Similarity = 0.0752
# Comparing IMG_0334.jpg and IMG_0441.jpg: Similarity = 0.0888
# Comparing IMG_0334.jpg and IMG_0442.jpg: Similarity = 0.1218
# Comparing IMG_0334.jpg and IMG_0443.jpg: Similarity = 0.1200
# Comparing IMG_0334.jpg and IMG_0444.jpg: Similarity = 0.1323
# Comparing IMG_0334.jpg and IMG_0447.jpg: Similarity = 0.1784
# Comparing IMG_0334.jpg and IMG_0448.jpg: Similarity = 0.1662
# Comparing IMG_0334.jpg and IMG_0449.jpg: Similarity = 0.1256
# Comparing IMG_0334.jpg and IMG_0450.jpg: Similarity = 0.1146
# Comparing IMG_0334.jpg and IMG_0451.jpg: Similarity = 0.1172
# Comparing IMG_0334.jpg and IMG_0452.jpg: Similarity = 0.1126
# Comparing IMG_0334.jpg and IMG_0453.jpg: Similarity = 0.1344
# Comparing IMG_0334.jpg and IMG_0454.jpg: Similarity = 0.1337
# Comparing IMG_0334.jpg and IMG_0455.jpg: Similarity = 0.1331
# Comparing IMG_0334.jpg and IMG_0456.jpg: Similarity = 0.0644
# Comparing IMG_0334.jpg and IMG_0458.jpg: Similarity = 0.0876
# Comparing IMG_0334.jpg and IMG_0459.jpg: Similarity = 0.1157
# Comparing IMG_0334.jpg and IMG_0460.jpg: Similarity = 0.1169
# Comparing IMG_0334.jpg and IMG_0461.jpg: Similarity = 0.1202
# Comparing IMG_0334.jpg and IMG_0462.jpg: Similarity = 0.1242
# Comparing IMG_0334.jpg and IMG_0463.jpg: Similarity = 0.1264
# Comparing IMG_0334.jpg and IMG_0464.jpg: Similarity = 0.1391
# Comparing IMG_0334.jpg and IMG_0465.jpg: Similarity = 0.1059
# Comparing IMG_0334.jpg and IMG_0466.jpg: Similarity = 0.0759
# Comparing IMG_0334.jpg and IMG_0467.jpg: Similarity = 0.0862
# Comparing IMG_0334.jpg and IMG_0469.jpg: Similarity = 0.0926
# Comparing IMG_0334.jpg and IMG_0470.jpg: Similarity = 0.0648
# Comparing IMG_0334.jpg and IMG_0472.jpg: Similarity = 0.0620
# Comparing IMG_0334.jpg and IMG_0473.jpg: Similarity = 0.0931
# Comparing IMG_0334.jpg and IMG_0474.jpg: Similarity = 0.0333
# Comparing IMG_0334.jpg and IMG_0475.jpg: Similarity = 0.1669
# Comparing IMG_0334.jpg and IMG_0476.jpg: Similarity = 0.1325
# Comparing IMG_0334.jpg and IMG_0477.jpg: Similarity = 0.1019
# Comparing IMG_0334.jpg and IMG_0478.jpg: Similarity = 0.1175
# Comparing IMG_0334.jpg and IMG_0480.jpg: Similarity = 0.1040
# Comparing IMG_0335.jpg and IMG_0336.jpg: Similarity = 0.5411
# Comparing IMG_0335.jpg and IMG_0337.jpg: Similarity = 0.5649
# Comparing IMG_0335.jpg and IMG_0339.jpg: Similarity = 0.0435
# Comparing IMG_0335.jpg and IMG_0341.jpg: Similarity = 0.1285
# Comparing IMG_0335.jpg and IMG_0345.JPG: Similarity = 0.0947
# Comparing IMG_0335.jpg and IMG_0346.JPG: Similarity = 0.0829
# Comparing IMG_0335.jpg and IMG_0350.jpg: Similarity = 0.1184
# Comparing IMG_0335.jpg and IMG_0352.jpg: Similarity = 0.1477
# Comparing IMG_0335.jpg and IMG_0353.jpg: Similarity = 0.0893
# Comparing IMG_0335.jpg and IMG_0354.jpg: Similarity = 0.0905
# Comparing IMG_0335.jpg and IMG_0355.jpg: Similarity = 0.1258
# Comparing IMG_0335.jpg and IMG_0356.jpg: Similarity = 0.0918
# Comparing IMG_0335.jpg and IMG_0357.jpg: Similarity = 0.0969
# Comparing IMG_0335.jpg and IMG_0358.jpg: Similarity = 0.0980
# Comparing IMG_0335.jpg and IMG_0361.jpg: Similarity = 0.1355
# Comparing IMG_0335.jpg and IMG_0362.jpg: Similarity = 0.1083
# Comparing IMG_0335.jpg and IMG_0363.jpg: Similarity = 0.0941
# Comparing IMG_0335.jpg and IMG_0364.jpg: Similarity = 0.1156
# Comparing IMG_0335.jpg and IMG_0366.jpg: Similarity = 0.0710
# Comparing IMG_0335.jpg and IMG_0367.jpg: Similarity = 0.0748
# Comparing IMG_0335.jpg and IMG_0368.jpg: Similarity = 0.0803
# Comparing IMG_0335.jpg and IMG_0369.jpg: Similarity = 0.0931
# Comparing IMG_0335.jpg and IMG_0370.jpg: Similarity = 0.0925
# Comparing IMG_0335.jpg and IMG_0371.JPG: Similarity = 0.1038
# Comparing IMG_0335.jpg and IMG_0372.JPG: Similarity = 0.0980
# Comparing IMG_0335.jpg and IMG_0373.JPG: Similarity = 0.0848
# Comparing IMG_0335.jpg and IMG_0374.JPG: Similarity = 0.1074
# Comparing IMG_0335.jpg and IMG_0376.JPG: Similarity = 0.0862
# Comparing IMG_0335.jpg and IMG_0382.jpg: Similarity = 0.2352
# Comparing IMG_0335.jpg and IMG_0383.jpg: Similarity = 0.2408
# Comparing IMG_0335.jpg and IMG_0384.jpg: Similarity = 0.2131
# Comparing IMG_0335.jpg and IMG_0385.jpg: Similarity = 0.1936
# Comparing IMG_0335.jpg and IMG_0386.jpg: Similarity = 0.0936
# Comparing IMG_0335.jpg and IMG_0389.jpg: Similarity = 0.1498
# Comparing IMG_0335.jpg and IMG_0390.jpg: Similarity = 0.2213
# Comparing IMG_0335.jpg and IMG_0391.jpg: Similarity = 0.1816
# Comparing IMG_0335.jpg and IMG_0392.jpg: Similarity = 0.0851
# Comparing IMG_0335.jpg and IMG_0393.jpg: Similarity = 0.1174
# Comparing IMG_0335.jpg and IMG_0395.jpg: Similarity = 0.1553
# Comparing IMG_0335.jpg and IMG_0396.jpg: Similarity = 0.1473
# Comparing IMG_0335.jpg and IMG_0397.jpg: Similarity = 0.1323
# Comparing IMG_0335.jpg and IMG_0398.jpg: Similarity = 0.1630
# Comparing IMG_0335.jpg and IMG_0399.jpg: Similarity = 0.1783
# Comparing IMG_0335.jpg and IMG_0401.jpg: Similarity = 0.2418
# Comparing IMG_0335.jpg and IMG_0402.jpg: Similarity = 0.2493
# Comparing IMG_0335.jpg and IMG_0403.jpg: Similarity = 0.2587
# Comparing IMG_0335.jpg and IMG_0404.jpg: Similarity = 0.2502
# Comparing IMG_0335.jpg and IMG_0406.jpg: Similarity = 0.1641
# Comparing IMG_0335.jpg and IMG_0407.jpg: Similarity = 0.1499
# Comparing IMG_0335.jpg and IMG_0408.jpg: Similarity = 0.0655
# Comparing IMG_0335.jpg and IMG_0409.jpg: Similarity = 0.0786
# Comparing IMG_0335.jpg and IMG_0414.JPG: Similarity = 0.0634
# Comparing IMG_0335.jpg and IMG_0416.jpg: Similarity = 0.1579
# Comparing IMG_0335.jpg and IMG_0419.jpg: Similarity = 0.0588
# Comparing IMG_0335.jpg and IMG_0420.jpg: Similarity = 0.0655
# Comparing IMG_0335.jpg and IMG_0421.jpg: Similarity = 0.0672
# Comparing IMG_0335.jpg and IMG_0422.jpg: Similarity = 0.0481
# Comparing IMG_0335.jpg and IMG_0423.jpg: Similarity = 0.0568
# Comparing IMG_0335.jpg and IMG_0424.jpg: Similarity = 0.1202
# Comparing IMG_0335.jpg and IMG_0425.jpg: Similarity = 0.1210
# Comparing IMG_0335.jpg and IMG_0431.jpg: Similarity = 0.1523
# Comparing IMG_0335.jpg and IMG_0432.jpg: Similarity = 0.1475
# Comparing IMG_0335.jpg and IMG_0433.jpg: Similarity = 0.1412
# Comparing IMG_0335.jpg and IMG_0434.jpg: Similarity = 0.1434
# Comparing IMG_0335.jpg and IMG_0435.jpg: Similarity = 0.1506
# Comparing IMG_0335.jpg and IMG_0436.jpg: Similarity = 0.1426
# Comparing IMG_0335.jpg and IMG_0437.jpg: Similarity = 0.1527
# Comparing IMG_0335.jpg and IMG_0438.jpg: Similarity = 0.0921
# Comparing IMG_0335.jpg and IMG_0439.jpg: Similarity = 0.0546
# Comparing IMG_0335.jpg and IMG_0440.jpg: Similarity = 0.0772
# Comparing IMG_0335.jpg and IMG_0441.jpg: Similarity = 0.0913
# Comparing IMG_0335.jpg and IMG_0442.jpg: Similarity = 0.1317
# Comparing IMG_0335.jpg and IMG_0443.jpg: Similarity = 0.1278
# Comparing IMG_0335.jpg and IMG_0444.jpg: Similarity = 0.1373
# Comparing IMG_0335.jpg and IMG_0447.jpg: Similarity = 0.1748
# Comparing IMG_0335.jpg and IMG_0448.jpg: Similarity = 0.1623
# Comparing IMG_0335.jpg and IMG_0449.jpg: Similarity = 0.1195
# Comparing IMG_0335.jpg and IMG_0450.jpg: Similarity = 0.1301
# Comparing IMG_0335.jpg and IMG_0451.jpg: Similarity = 0.1253
# Comparing IMG_0335.jpg and IMG_0452.jpg: Similarity = 0.1232
# Comparing IMG_0335.jpg and IMG_0453.jpg: Similarity = 0.1271
# Comparing IMG_0335.jpg and IMG_0454.jpg: Similarity = 0.1280
# Comparing IMG_0335.jpg and IMG_0455.jpg: Similarity = 0.1260
# Comparing IMG_0335.jpg and IMG_0456.jpg: Similarity = 0.0695
# Comparing IMG_0335.jpg and IMG_0458.jpg: Similarity = 0.0903
# Comparing IMG_0335.jpg and IMG_0459.jpg: Similarity = 0.1131
# Comparing IMG_0335.jpg and IMG_0460.jpg: Similarity = 0.1109
# Comparing IMG_0335.jpg and IMG_0461.jpg: Similarity = 0.1139
# Comparing IMG_0335.jpg and IMG_0462.jpg: Similarity = 0.1465
# Comparing IMG_0335.jpg and IMG_0463.jpg: Similarity = 0.1496
# Comparing IMG_0335.jpg and IMG_0464.jpg: Similarity = 0.1581
# Comparing IMG_0335.jpg and IMG_0465.jpg: Similarity = 0.1254
# Comparing IMG_0335.jpg and IMG_0466.jpg: Similarity = 0.0655
# Comparing IMG_0335.jpg and IMG_0467.jpg: Similarity = 0.0748
# Comparing IMG_0335.jpg and IMG_0469.jpg: Similarity = 0.0879
# Comparing IMG_0335.jpg and IMG_0470.jpg: Similarity = 0.0556
# Comparing IMG_0335.jpg and IMG_0472.jpg: Similarity = 0.0609
# Comparing IMG_0335.jpg and IMG_0473.jpg: Similarity = 0.0902
# Comparing IMG_0335.jpg and IMG_0474.jpg: Similarity = 0.0335
# Comparing IMG_0335.jpg and IMG_0475.jpg: Similarity = 0.1735
# Comparing IMG_0335.jpg and IMG_0476.jpg: Similarity = 0.1529
# Comparing IMG_0335.jpg and IMG_0477.jpg: Similarity = 0.1005
# Comparing IMG_0335.jpg and IMG_0478.jpg: Similarity = 0.1153
# Comparing IMG_0335.jpg and IMG_0480.jpg: Similarity = 0.1021
# Comparing IMG_0336.jpg and IMG_0337.jpg: Similarity = 0.8070
# Comparing IMG_0336.jpg and IMG_0339.jpg: Similarity = 0.0410
# Comparing IMG_0336.jpg and IMG_0341.jpg: Similarity = 0.0809
# Comparing IMG_0336.jpg and IMG_0345.JPG: Similarity = 0.0683
# Comparing IMG_0336.jpg and IMG_0346.JPG: Similarity = 0.0629
# Comparing IMG_0336.jpg and IMG_0350.jpg: Similarity = 0.1160
# Comparing IMG_0336.jpg and IMG_0352.jpg: Similarity = 0.1627
# Comparing IMG_0336.jpg and IMG_0353.jpg: Similarity = 0.1018
# Comparing IMG_0336.jpg and IMG_0354.jpg: Similarity = 0.1119
# Comparing IMG_0336.jpg and IMG_0355.jpg: Similarity = 0.1189
# Comparing IMG_0336.jpg and IMG_0356.jpg: Similarity = 0.1152
# Comparing IMG_0336.jpg and IMG_0357.jpg: Similarity = 0.1190
# Comparing IMG_0336.jpg and IMG_0358.jpg: Similarity = 0.1013
# Comparing IMG_0336.jpg and IMG_0361.jpg: Similarity = 0.1174
# Comparing IMG_0336.jpg and IMG_0362.jpg: Similarity = 0.1017
# Comparing IMG_0336.jpg and IMG_0363.jpg: Similarity = 0.0943
# Comparing IMG_0336.jpg and IMG_0364.jpg: Similarity = 0.1109
# Comparing IMG_0336.jpg and IMG_0366.jpg: Similarity = 0.0582
# Comparing IMG_0336.jpg and IMG_0367.jpg: Similarity = 0.0553
# Comparing IMG_0336.jpg and IMG_0368.jpg: Similarity = 0.0601
# Comparing IMG_0336.jpg and IMG_0369.jpg: Similarity = 0.0709
# Comparing IMG_0336.jpg and IMG_0370.jpg: Similarity = 0.0662
# Comparing IMG_0336.jpg and IMG_0371.JPG: Similarity = 0.0839
# Comparing IMG_0336.jpg and IMG_0372.JPG: Similarity = 0.0843
# Comparing IMG_0336.jpg and IMG_0373.JPG: Similarity = 0.0759
# Comparing IMG_0336.jpg and IMG_0374.JPG: Similarity = 0.0845
# Comparing IMG_0336.jpg and IMG_0376.JPG: Similarity = 0.0700
# Comparing IMG_0336.jpg and IMG_0382.jpg: Similarity = 0.1943
# Comparing IMG_0336.jpg and IMG_0383.jpg: Similarity = 0.1776
# Comparing IMG_0336.jpg and IMG_0384.jpg: Similarity = 0.1552
# Comparing IMG_0336.jpg and IMG_0385.jpg: Similarity = 0.1627
# Comparing IMG_0336.jpg and IMG_0386.jpg: Similarity = 0.0769
# Comparing IMG_0336.jpg and IMG_0389.jpg: Similarity = 0.1154
# Comparing IMG_0336.jpg and IMG_0390.jpg: Similarity = 0.1726
# Comparing IMG_0336.jpg and IMG_0391.jpg: Similarity = 0.1549
# Comparing IMG_0336.jpg and IMG_0392.jpg: Similarity = 0.0909
# Comparing IMG_0336.jpg and IMG_0393.jpg: Similarity = 0.0995
# Comparing IMG_0336.jpg and IMG_0395.jpg: Similarity = 0.1281
# Comparing IMG_0336.jpg and IMG_0396.jpg: Similarity = 0.1315
# Comparing IMG_0336.jpg and IMG_0397.jpg: Similarity = 0.0959
# Comparing IMG_0336.jpg and IMG_0398.jpg: Similarity = 0.1343
# Comparing IMG_0336.jpg and IMG_0399.jpg: Similarity = 0.1537
# Comparing IMG_0336.jpg and IMG_0401.jpg: Similarity = 0.1836
# Comparing IMG_0336.jpg and IMG_0402.jpg: Similarity = 0.1819
# Comparing IMG_0336.jpg and IMG_0403.jpg: Similarity = 0.2045
# Comparing IMG_0336.jpg and IMG_0404.jpg: Similarity = 0.2095
# Comparing IMG_0336.jpg and IMG_0406.jpg: Similarity = 0.1478
# Comparing IMG_0336.jpg and IMG_0407.jpg: Similarity = 0.1076
# Comparing IMG_0336.jpg and IMG_0408.jpg: Similarity = 0.0297
# Comparing IMG_0336.jpg and IMG_0409.jpg: Similarity = 0.0485
# Comparing IMG_0336.jpg and IMG_0414.JPG: Similarity = 0.0513
# Comparing IMG_0336.jpg and IMG_0416.jpg: Similarity = 0.1003
# Comparing IMG_0336.jpg and IMG_0419.jpg: Similarity = 0.0500
# Comparing IMG_0336.jpg and IMG_0420.jpg: Similarity = 0.0581
# Comparing IMG_0336.jpg and IMG_0421.jpg: Similarity = 0.0587
# Comparing IMG_0336.jpg and IMG_0422.jpg: Similarity = 0.0321
# Comparing IMG_0336.jpg and IMG_0423.jpg: Similarity = 0.0461
# Comparing IMG_0336.jpg and IMG_0424.jpg: Similarity = 0.0893
# Comparing IMG_0336.jpg and IMG_0425.jpg: Similarity = 0.0930
# Comparing IMG_0336.jpg and IMG_0431.jpg: Similarity = 0.1151
# Comparing IMG_0336.jpg and IMG_0432.jpg: Similarity = 0.1121
# Comparing IMG_0336.jpg and IMG_0433.jpg: Similarity = 0.1042
# Comparing IMG_0336.jpg and IMG_0434.jpg: Similarity = 0.1067
# Comparing IMG_0336.jpg and IMG_0435.jpg: Similarity = 0.1121
# Comparing IMG_0336.jpg and IMG_0436.jpg: Similarity = 0.1124
# Comparing IMG_0336.jpg and IMG_0437.jpg: Similarity = 0.1133
# Comparing IMG_0336.jpg and IMG_0438.jpg: Similarity = 0.0646
# Comparing IMG_0336.jpg and IMG_0439.jpg: Similarity = 0.0320
# Comparing IMG_0336.jpg and IMG_0440.jpg: Similarity = 0.0610
# Comparing IMG_0336.jpg and IMG_0441.jpg: Similarity = 0.0681
# Comparing IMG_0336.jpg and IMG_0442.jpg: Similarity = 0.0906
# Comparing IMG_0336.jpg and IMG_0443.jpg: Similarity = 0.0977
# Comparing IMG_0336.jpg and IMG_0444.jpg: Similarity = 0.1054
# Comparing IMG_0336.jpg and IMG_0447.jpg: Similarity = 0.1049
# Comparing IMG_0336.jpg and IMG_0448.jpg: Similarity = 0.1060
# Comparing IMG_0336.jpg and IMG_0449.jpg: Similarity = 0.0731
# Comparing IMG_0336.jpg and IMG_0450.jpg: Similarity = 0.0972
# Comparing IMG_0336.jpg and IMG_0451.jpg: Similarity = 0.0796
# Comparing IMG_0336.jpg and IMG_0452.jpg: Similarity = 0.0950
# Comparing IMG_0336.jpg and IMG_0453.jpg: Similarity = 0.1153
# Comparing IMG_0336.jpg and IMG_0454.jpg: Similarity = 0.1108
# Comparing IMG_0336.jpg and IMG_0455.jpg: Similarity = 0.1090
# Comparing IMG_0336.jpg and IMG_0456.jpg: Similarity = 0.0695
# Comparing IMG_0336.jpg and IMG_0458.jpg: Similarity = 0.0720
# Comparing IMG_0336.jpg and IMG_0459.jpg: Similarity = 0.0811
# Comparing IMG_0336.jpg and IMG_0460.jpg: Similarity = 0.0890
# Comparing IMG_0336.jpg and IMG_0461.jpg: Similarity = 0.0925
# Comparing IMG_0336.jpg and IMG_0462.jpg: Similarity = 0.1046
# Comparing IMG_0336.jpg and IMG_0463.jpg: Similarity = 0.1113
# Comparing IMG_0336.jpg and IMG_0464.jpg: Similarity = 0.1185
# Comparing IMG_0336.jpg and IMG_0465.jpg: Similarity = 0.0921
# Comparing IMG_0336.jpg and IMG_0466.jpg: Similarity = 0.0519
# Comparing IMG_0336.jpg and IMG_0467.jpg: Similarity = 0.0617
# Comparing IMG_0336.jpg and IMG_0469.jpg: Similarity = 0.0624
# Comparing IMG_0336.jpg and IMG_0470.jpg: Similarity = 0.0646
# Comparing IMG_0336.jpg and IMG_0472.jpg: Similarity = 0.0534
# Comparing IMG_0336.jpg and IMG_0473.jpg: Similarity = 0.0827
# Comparing IMG_0336.jpg and IMG_0474.jpg: Similarity = 0.0526
# Comparing IMG_0336.jpg and IMG_0475.jpg: Similarity = 0.1224
# Comparing IMG_0336.jpg and IMG_0476.jpg: Similarity = 0.0960
# Comparing IMG_0336.jpg and IMG_0477.jpg: Similarity = 0.0619
# Comparing IMG_0336.jpg and IMG_0478.jpg: Similarity = 0.0724
# Comparing IMG_0336.jpg and IMG_0480.jpg: Similarity = 0.0699
# Comparing IMG_0337.jpg and IMG_0339.jpg: Similarity = 0.0410
# Comparing IMG_0337.jpg and IMG_0341.jpg: Similarity = 0.0863
# Comparing IMG_0337.jpg and IMG_0345.JPG: Similarity = 0.0770
# Comparing IMG_0337.jpg and IMG_0346.JPG: Similarity = 0.0659
# Comparing IMG_0337.jpg and IMG_0350.jpg: Similarity = 0.1175
# Comparing IMG_0337.jpg and IMG_0352.jpg: Similarity = 0.1498
# Comparing IMG_0337.jpg and IMG_0353.jpg: Similarity = 0.0949
# Comparing IMG_0337.jpg and IMG_0354.jpg: Similarity = 0.1032
# Comparing IMG_0337.jpg and IMG_0355.jpg: Similarity = 0.1135
# Comparing IMG_0337.jpg and IMG_0356.jpg: Similarity = 0.1029
# Comparing IMG_0337.jpg and IMG_0357.jpg: Similarity = 0.1082
# Comparing IMG_0337.jpg and IMG_0358.jpg: Similarity = 0.0958
# Comparing IMG_0337.jpg and IMG_0361.jpg: Similarity = 0.0991
# Comparing IMG_0337.jpg and IMG_0362.jpg: Similarity = 0.0984
# Comparing IMG_0337.jpg and IMG_0363.jpg: Similarity = 0.0904
# Comparing IMG_0337.jpg and IMG_0364.jpg: Similarity = 0.1083
# Comparing IMG_0337.jpg and IMG_0366.jpg: Similarity = 0.0576
# Comparing IMG_0337.jpg and IMG_0367.jpg: Similarity = 0.0683
# Comparing IMG_0337.jpg and IMG_0368.jpg: Similarity = 0.0820
# Comparing IMG_0337.jpg and IMG_0369.jpg: Similarity = 0.0836
# Comparing IMG_0337.jpg and IMG_0370.jpg: Similarity = 0.0840
# Comparing IMG_0337.jpg and IMG_0371.JPG: Similarity = 0.0802
# Comparing IMG_0337.jpg and IMG_0372.JPG: Similarity = 0.0777
# Comparing IMG_0337.jpg and IMG_0373.JPG: Similarity = 0.0786
# Comparing IMG_0337.jpg and IMG_0374.JPG: Similarity = 0.0799
# Comparing IMG_0337.jpg and IMG_0376.JPG: Similarity = 0.0576
# Comparing IMG_0337.jpg and IMG_0382.jpg: Similarity = 0.2026
# Comparing IMG_0337.jpg and IMG_0383.jpg: Similarity = 0.2012
# Comparing IMG_0337.jpg and IMG_0384.jpg: Similarity = 0.1827
# Comparing IMG_0337.jpg and IMG_0385.jpg: Similarity = 0.1844
# Comparing IMG_0337.jpg and IMG_0386.jpg: Similarity = 0.0920
# Comparing IMG_0337.jpg and IMG_0389.jpg: Similarity = 0.1342
# Comparing IMG_0337.jpg and IMG_0390.jpg: Similarity = 0.1827
# Comparing IMG_0337.jpg and IMG_0391.jpg: Similarity = 0.1753
# Comparing IMG_0337.jpg and IMG_0392.jpg: Similarity = 0.0926
# Comparing IMG_0337.jpg and IMG_0393.jpg: Similarity = 0.1035
# Comparing IMG_0337.jpg and IMG_0395.jpg: Similarity = 0.1084
# Comparing IMG_0337.jpg and IMG_0396.jpg: Similarity = 0.1113
# Comparing IMG_0337.jpg and IMG_0397.jpg: Similarity = 0.0789
# Comparing IMG_0337.jpg and IMG_0398.jpg: Similarity = 0.1119
# Comparing IMG_0337.jpg and IMG_0399.jpg: Similarity = 0.1333
# Comparing IMG_0337.jpg and IMG_0401.jpg: Similarity = 0.1717
# Comparing IMG_0337.jpg and IMG_0402.jpg: Similarity = 0.1776
# Comparing IMG_0337.jpg and IMG_0403.jpg: Similarity = 0.1954
# Comparing IMG_0337.jpg and IMG_0404.jpg: Similarity = 0.2087
# Comparing IMG_0337.jpg and IMG_0406.jpg: Similarity = 0.1310
# Comparing IMG_0337.jpg and IMG_0407.jpg: Similarity = 0.0921
# Comparing IMG_0337.jpg and IMG_0408.jpg: Similarity = 0.0329
# Comparing IMG_0337.jpg and IMG_0409.jpg: Similarity = 0.0375
# Comparing IMG_0337.jpg and IMG_0414.JPG: Similarity = 0.0530
# Comparing IMG_0337.jpg and IMG_0416.jpg: Similarity = 0.1074
# Comparing IMG_0337.jpg and IMG_0419.jpg: Similarity = 0.0513
# Comparing IMG_0337.jpg and IMG_0420.jpg: Similarity = 0.0576
# Comparing IMG_0337.jpg and IMG_0421.jpg: Similarity = 0.0580
# Comparing IMG_0337.jpg and IMG_0422.jpg: Similarity = 0.0389
# Comparing IMG_0337.jpg and IMG_0423.jpg: Similarity = 0.0466
# Comparing IMG_0337.jpg and IMG_0424.jpg: Similarity = 0.1009
# Comparing IMG_0337.jpg and IMG_0425.jpg: Similarity = 0.0961
# Comparing IMG_0337.jpg and IMG_0431.jpg: Similarity = 0.1207
# Comparing IMG_0337.jpg and IMG_0432.jpg: Similarity = 0.1165
# Comparing IMG_0337.jpg and IMG_0433.jpg: Similarity = 0.1039
# Comparing IMG_0337.jpg and IMG_0434.jpg: Similarity = 0.1098
# Comparing IMG_0337.jpg and IMG_0435.jpg: Similarity = 0.1159
# Comparing IMG_0337.jpg and IMG_0436.jpg: Similarity = 0.1177
# Comparing IMG_0337.jpg and IMG_0437.jpg: Similarity = 0.1210
# Comparing IMG_0337.jpg and IMG_0438.jpg: Similarity = 0.0684
# Comparing IMG_0337.jpg and IMG_0439.jpg: Similarity = 0.0360
# Comparing IMG_0337.jpg and IMG_0440.jpg: Similarity = 0.0666
# Comparing IMG_0337.jpg and IMG_0441.jpg: Similarity = 0.0772
# Comparing IMG_0337.jpg and IMG_0442.jpg: Similarity = 0.1075
# Comparing IMG_0337.jpg and IMG_0443.jpg: Similarity = 0.1156
# Comparing IMG_0337.jpg and IMG_0444.jpg: Similarity = 0.1240
# Comparing IMG_0337.jpg and IMG_0447.jpg: Similarity = 0.1000
# Comparing IMG_0337.jpg and IMG_0448.jpg: Similarity = 0.0981
# Comparing IMG_0337.jpg and IMG_0449.jpg: Similarity = 0.0771
# Comparing IMG_0337.jpg and IMG_0450.jpg: Similarity = 0.0971
# Comparing IMG_0337.jpg and IMG_0451.jpg: Similarity = 0.0832
# Comparing IMG_0337.jpg and IMG_0452.jpg: Similarity = 0.1240
# Comparing IMG_0337.jpg and IMG_0453.jpg: Similarity = 0.1030
# Comparing IMG_0337.jpg and IMG_0454.jpg: Similarity = 0.0995
# Comparing IMG_0337.jpg and IMG_0455.jpg: Similarity = 0.0956
# Comparing IMG_0337.jpg and IMG_0456.jpg: Similarity = 0.0771
# Comparing IMG_0337.jpg and IMG_0458.jpg: Similarity = 0.0736
# Comparing IMG_0337.jpg and IMG_0459.jpg: Similarity = 0.0749
# Comparing IMG_0337.jpg and IMG_0460.jpg: Similarity = 0.0824
# Comparing IMG_0337.jpg and IMG_0461.jpg: Similarity = 0.0849
# Comparing IMG_0337.jpg and IMG_0462.jpg: Similarity = 0.1134
# Comparing IMG_0337.jpg and IMG_0463.jpg: Similarity = 0.1212
# Comparing IMG_0337.jpg and IMG_0464.jpg: Similarity = 0.1219
# Comparing IMG_0337.jpg and IMG_0465.jpg: Similarity = 0.1027
# Comparing IMG_0337.jpg and IMG_0466.jpg: Similarity = 0.0594
# Comparing IMG_0337.jpg and IMG_0467.jpg: Similarity = 0.0699
# Comparing IMG_0337.jpg and IMG_0469.jpg: Similarity = 0.0692
# Comparing IMG_0337.jpg and IMG_0470.jpg: Similarity = 0.0587
# Comparing IMG_0337.jpg and IMG_0472.jpg: Similarity = 0.0477
# Comparing IMG_0337.jpg and IMG_0473.jpg: Similarity = 0.0805
# Comparing IMG_0337.jpg and IMG_0474.jpg: Similarity = 0.0417
# Comparing IMG_0337.jpg and IMG_0475.jpg: Similarity = 0.1301
# Comparing IMG_0337.jpg and IMG_0476.jpg: Similarity = 0.1174
# Comparing IMG_0337.jpg and IMG_0477.jpg: Similarity = 0.0634
# Comparing IMG_0337.jpg and IMG_0478.jpg: Similarity = 0.0755
# Comparing IMG_0337.jpg and IMG_0480.jpg: Similarity = 0.0736
# Comparing IMG_0339.jpg and IMG_0341.jpg: Similarity = 0.0707
# Comparing IMG_0339.jpg and IMG_0345.JPG: Similarity = 0.0357
# Comparing IMG_0339.jpg and IMG_0346.JPG: Similarity = 0.0426
# Comparing IMG_0339.jpg and IMG_0350.jpg: Similarity = 0.0527
# Comparing IMG_0339.jpg and IMG_0352.jpg: Similarity = 0.0683
# Comparing IMG_0339.jpg and IMG_0353.jpg: Similarity = 0.0578
# Comparing IMG_0339.jpg and IMG_0354.jpg: Similarity = 0.0521
# Comparing IMG_0339.jpg and IMG_0355.jpg: Similarity = 0.0499
# Comparing IMG_0339.jpg and IMG_0356.jpg: Similarity = 0.0519
# Comparing IMG_0339.jpg and IMG_0357.jpg: Similarity = 0.0510
# Comparing IMG_0339.jpg and IMG_0358.jpg: Similarity = 0.0663
# Comparing IMG_0339.jpg and IMG_0361.jpg: Similarity = 0.0783
# Comparing IMG_0339.jpg and IMG_0362.jpg: Similarity = 0.0950
# Comparing IMG_0339.jpg and IMG_0363.jpg: Similarity = 0.1179
# Comparing IMG_0339.jpg and IMG_0364.jpg: Similarity = 0.1249
# Comparing IMG_0339.jpg and IMG_0366.jpg: Similarity = 0.0538
# Comparing IMG_0339.jpg and IMG_0367.jpg: Similarity = 0.0499
# Comparing IMG_0339.jpg and IMG_0368.jpg: Similarity = 0.0484
# Comparing IMG_0339.jpg and IMG_0369.jpg: Similarity = 0.0546
# Comparing IMG_0339.jpg and IMG_0370.jpg: Similarity = 0.0430
# Comparing IMG_0339.jpg and IMG_0371.JPG: Similarity = 0.0558
# Comparing IMG_0339.jpg and IMG_0372.JPG: Similarity = 0.0457
# Comparing IMG_0339.jpg and IMG_0373.JPG: Similarity = 0.0427
# Comparing IMG_0339.jpg and IMG_0374.JPG: Similarity = 0.0509
# Comparing IMG_0339.jpg and IMG_0376.JPG: Similarity = 0.0512
# Comparing IMG_0339.jpg and IMG_0382.jpg: Similarity = 0.0638
# Comparing IMG_0339.jpg and IMG_0383.jpg: Similarity = 0.0321
# Comparing IMG_0339.jpg and IMG_0384.jpg: Similarity = 0.0466
# Comparing IMG_0339.jpg and IMG_0385.jpg: Similarity = 0.0516
# Comparing IMG_0339.jpg and IMG_0386.jpg: Similarity = 0.0305
# Comparing IMG_0339.jpg and IMG_0389.jpg: Similarity = 0.0294
# Comparing IMG_0339.jpg and IMG_0390.jpg: Similarity = 0.0473
# Comparing IMG_0339.jpg and IMG_0391.jpg: Similarity = 0.0320
# Comparing IMG_0339.jpg and IMG_0392.jpg: Similarity = 0.0287
# Comparing IMG_0339.jpg and IMG_0393.jpg: Similarity = 0.0250
# Comparing IMG_0339.jpg and IMG_0395.jpg: Similarity = 0.0465
# Comparing IMG_0339.jpg and IMG_0396.jpg: Similarity = 0.0444
# Comparing IMG_0339.jpg and IMG_0397.jpg: Similarity = 0.0462
# Comparing IMG_0339.jpg and IMG_0398.jpg: Similarity = 0.0504
# Comparing IMG_0339.jpg and IMG_0399.jpg: Similarity = 0.0478
# Comparing IMG_0339.jpg and IMG_0401.jpg: Similarity = 0.0575
# Comparing IMG_0339.jpg and IMG_0402.jpg: Similarity = 0.0520
# Comparing IMG_0339.jpg and IMG_0403.jpg: Similarity = 0.0536
# Comparing IMG_0339.jpg and IMG_0404.jpg: Similarity = 0.0574
# Comparing IMG_0339.jpg and IMG_0406.jpg: Similarity = 0.0467
# Comparing IMG_0339.jpg and IMG_0407.jpg: Similarity = 0.0353
# Comparing IMG_0339.jpg and IMG_0408.jpg: Similarity = 0.0335
# Comparing IMG_0339.jpg and IMG_0409.jpg: Similarity = 0.0443
# Comparing IMG_0339.jpg and IMG_0414.JPG: Similarity = 0.0785
# Comparing IMG_0339.jpg and IMG_0416.jpg: Similarity = 0.0478
# Comparing IMG_0339.jpg and IMG_0419.jpg: Similarity = 0.3081
# Comparing IMG_0339.jpg and IMG_0420.jpg: Similarity = 0.1995
# Comparing IMG_0339.jpg and IMG_0421.jpg: Similarity = 0.2083
# Comparing IMG_0339.jpg and IMG_0422.jpg: Similarity = 0.0514
# Comparing IMG_0339.jpg and IMG_0423.jpg: Similarity = 0.0606
# Comparing IMG_0339.jpg and IMG_0424.jpg: Similarity = 0.0379
# Comparing IMG_0339.jpg and IMG_0425.jpg: Similarity = 0.0402
# Comparing IMG_0339.jpg and IMG_0431.jpg: Similarity = 0.0578
# Comparing IMG_0339.jpg and IMG_0432.jpg: Similarity = 0.0608
# Comparing IMG_0339.jpg and IMG_0433.jpg: Similarity = 0.0591
# Comparing IMG_0339.jpg and IMG_0434.jpg: Similarity = 0.0582
# Comparing IMG_0339.jpg and IMG_0435.jpg: Similarity = 0.0717
# Comparing IMG_0339.jpg and IMG_0436.jpg: Similarity = 0.0621
# ...
# Comparing IMG_0455.jpg and IMG_0477.jpg: Similarity = 0.0936
# Comparing IMG_0455.jpg and IMG_0478.jpg: Similarity = 0.1057
# Comparing IMG_0455.jpg and IMG_0480.jpg: Similarity = 0.0800
# Comparing IMG_0456.jpg and IMG_0458.jpg: Similarity = 0.1389
# Comparing IMG_0456.jpg and IMG_0459.jpg: Similarity = 0.1100
# Comparing IMG_0456.jpg and IMG_0460.jpg: Similarity = 0.0814
# Comparing IMG_0456.jpg and IMG_0461.jpg: Similarity = 0.0897
# Comparing IMG_0456.jpg and IMG_0462.jpg: Similarity = 0.1936
# Comparing IMG_0456.jpg and IMG_0463.jpg: Similarity = 0.2889
# Comparing IMG_0456.jpg and IMG_0464.jpg: Similarity = 0.1657
# Comparing IMG_0456.jpg and IMG_0465.jpg: Similarity = 0.1879
# Comparing IMG_0456.jpg and IMG_0466.jpg: Similarity = 0.0448
# Comparing IMG_0456.jpg and IMG_0467.jpg: Similarity = 0.0368
# Comparing IMG_0456.jpg and IMG_0469.jpg: Similarity = 0.0611
# Comparing IMG_0456.jpg and IMG_0470.jpg: Similarity = 0.0451
# Comparing IMG_0456.jpg and IMG_0472.jpg: Similarity = 0.0507
# Comparing IMG_0456.jpg and IMG_0473.jpg: Similarity = 0.0789
# Comparing IMG_0456.jpg and IMG_0474.jpg: Similarity = 0.0388
# Comparing IMG_0456.jpg and IMG_0475.jpg: Similarity = 0.0897
# Comparing IMG_0456.jpg and IMG_0476.jpg: Similarity = 0.1204
# Comparing IMG_0456.jpg and IMG_0477.jpg: Similarity = 0.1407
# Comparing IMG_0456.jpg and IMG_0478.jpg: Similarity = 0.1217
# Comparing IMG_0456.jpg and IMG_0480.jpg: Similarity = 0.1275
# Comparing IMG_0458.jpg and IMG_0459.jpg: Similarity = 0.6373
# Moved duplicate image to dupes folder: IMG_0459.jpg
# Comparing IMG_0458.jpg and IMG_0460.jpg: Similarity = 0.6242
# Moved duplicate image to dupes folder: IMG_0460.jpg
# Comparing IMG_0458.jpg and IMG_0461.jpg: Similarity = 0.6418
# Moved duplicate image to dupes folder: IMG_0461.jpg
# Comparing IMG_0458.jpg and IMG_0462.jpg: Similarity = 0.0865
# Comparing IMG_0458.jpg and IMG_0463.jpg: Similarity = 0.0963
# Comparing IMG_0458.jpg and IMG_0464.jpg: Similarity = 0.1137
# Comparing IMG_0458.jpg and IMG_0465.jpg: Similarity = 0.1094
# Comparing IMG_0458.jpg and IMG_0466.jpg: Similarity = 0.0374
# Comparing IMG_0458.jpg and IMG_0467.jpg: Similarity = 0.0334
# Comparing IMG_0458.jpg and IMG_0469.jpg: Similarity = 0.0953
# Comparing IMG_0458.jpg and IMG_0470.jpg: Similarity = 0.0515
# Comparing IMG_0458.jpg and IMG_0472.jpg: Similarity = 0.0811
# Comparing IMG_0458.jpg and IMG_0473.jpg: Similarity = 0.0511
# Comparing IMG_0458.jpg and IMG_0474.jpg: Similarity = 0.0437
# Comparing IMG_0458.jpg and IMG_0475.jpg: Similarity = 0.1060
# Comparing IMG_0458.jpg and IMG_0476.jpg: Similarity = 0.1342
# Comparing IMG_0458.jpg and IMG_0477.jpg: Similarity = 0.0393
# Comparing IMG_0458.jpg and IMG_0478.jpg: Similarity = 0.0362
# Comparing IMG_0458.jpg and IMG_0480.jpg: Similarity = 0.0379
# Comparing IMG_0459.jpg and IMG_0460.jpg: Similarity = 0.6722
# Comparing IMG_0459.jpg and IMG_0461.jpg: Similarity = 0.6835
# Comparing IMG_0459.jpg and IMG_0462.jpg: Similarity = 0.1026
# Comparing IMG_0459.jpg and IMG_0463.jpg: Similarity = 0.1282
# Comparing IMG_0459.jpg and IMG_0464.jpg: Similarity = 0.1774
# Comparing IMG_0459.jpg and IMG_0465.jpg: Similarity = 0.1204
# Comparing IMG_0459.jpg and IMG_0466.jpg: Similarity = 0.0385
# Comparing IMG_0459.jpg and IMG_0467.jpg: Similarity = 0.0299
# Comparing IMG_0459.jpg and IMG_0469.jpg: Similarity = 0.0975
# Comparing IMG_0459.jpg and IMG_0470.jpg: Similarity = 0.0440
# Comparing IMG_0459.jpg and IMG_0472.jpg: Similarity = 0.0659
# Comparing IMG_0459.jpg and IMG_0473.jpg: Similarity = 0.0451
# Comparing IMG_0459.jpg and IMG_0474.jpg: Similarity = 0.0440
# Comparing IMG_0459.jpg and IMG_0475.jpg: Similarity = 0.1251
# Comparing IMG_0459.jpg and IMG_0476.jpg: Similarity = 0.1353
# Comparing IMG_0459.jpg and IMG_0477.jpg: Similarity = 0.0710
# Comparing IMG_0459.jpg and IMG_0478.jpg: Similarity = 0.0680
# Comparing IMG_0459.jpg and IMG_0480.jpg: Similarity = 0.0654
# Comparing IMG_0460.jpg and IMG_0461.jpg: Similarity = 0.9610
# Comparing IMG_0460.jpg and IMG_0462.jpg: Similarity = 0.1008
# Comparing IMG_0460.jpg and IMG_0463.jpg: Similarity = 0.1222
# Comparing IMG_0460.jpg and IMG_0464.jpg: Similarity = 0.1188
# Comparing IMG_0460.jpg and IMG_0465.jpg: Similarity = 0.0860
# Comparing IMG_0460.jpg and IMG_0466.jpg: Similarity = 0.0389
# Comparing IMG_0460.jpg and IMG_0467.jpg: Similarity = 0.0321
# Comparing IMG_0460.jpg and IMG_0469.jpg: Similarity = 0.1063
# Comparing IMG_0460.jpg and IMG_0470.jpg: Similarity = 0.0415
# Comparing IMG_0460.jpg and IMG_0472.jpg: Similarity = 0.0586
# Comparing IMG_0460.jpg and IMG_0473.jpg: Similarity = 0.0496
# Comparing IMG_0460.jpg and IMG_0474.jpg: Similarity = 0.0425
# Comparing IMG_0460.jpg and IMG_0475.jpg: Similarity = 0.1065
# Comparing IMG_0460.jpg and IMG_0476.jpg: Similarity = 0.1206
# Comparing IMG_0460.jpg and IMG_0477.jpg: Similarity = 0.0618
# Comparing IMG_0460.jpg and IMG_0478.jpg: Similarity = 0.0600
# Comparing IMG_0460.jpg and IMG_0480.jpg: Similarity = 0.0577
# Comparing IMG_0461.jpg and IMG_0462.jpg: Similarity = 0.1015
# Comparing IMG_0461.jpg and IMG_0463.jpg: Similarity = 0.1262
# Comparing IMG_0461.jpg and IMG_0464.jpg: Similarity = 0.1297
# Comparing IMG_0461.jpg and IMG_0465.jpg: Similarity = 0.0958
# Comparing IMG_0461.jpg and IMG_0466.jpg: Similarity = 0.0405
# Comparing IMG_0461.jpg and IMG_0467.jpg: Similarity = 0.0334
# Comparing IMG_0461.jpg and IMG_0469.jpg: Similarity = 0.1061
# Comparing IMG_0461.jpg and IMG_0470.jpg: Similarity = 0.0430
# Comparing IMG_0461.jpg and IMG_0472.jpg: Similarity = 0.0583
# Comparing IMG_0461.jpg and IMG_0473.jpg: Similarity = 0.0522
# Comparing IMG_0461.jpg and IMG_0474.jpg: Similarity = 0.0442
# Comparing IMG_0461.jpg and IMG_0475.jpg: Similarity = 0.1147
# Comparing IMG_0461.jpg and IMG_0476.jpg: Similarity = 0.1279
# Comparing IMG_0461.jpg and IMG_0477.jpg: Similarity = 0.0633
# Comparing IMG_0461.jpg and IMG_0478.jpg: Similarity = 0.0625
# Comparing IMG_0461.jpg and IMG_0480.jpg: Similarity = 0.0604
# Comparing IMG_0462.jpg and IMG_0463.jpg: Similarity = 0.3638
# Comparing IMG_0462.jpg and IMG_0464.jpg: Similarity = 0.4875
# Comparing IMG_0462.jpg and IMG_0465.jpg: Similarity = 0.5272
# Moved duplicate image to dupes folder: IMG_0465.jpg
# Comparing IMG_0462.jpg and IMG_0466.jpg: Similarity = 0.0393
# Comparing IMG_0462.jpg and IMG_0467.jpg: Similarity = 0.0384
# Comparing IMG_0462.jpg and IMG_0469.jpg: Similarity = 0.0639
# Comparing IMG_0462.jpg and IMG_0470.jpg: Similarity = 0.0329
# Comparing IMG_0462.jpg and IMG_0472.jpg: Similarity = 0.0518
# Comparing IMG_0462.jpg and IMG_0473.jpg: Similarity = 0.0724
# Comparing IMG_0462.jpg and IMG_0474.jpg: Similarity = 0.0455
# Comparing IMG_0462.jpg and IMG_0475.jpg: Similarity = 0.1413
# Comparing IMG_0462.jpg and IMG_0476.jpg: Similarity = 0.1894
# Comparing IMG_0462.jpg and IMG_0477.jpg: Similarity = 0.1560
# Comparing IMG_0462.jpg and IMG_0478.jpg: Similarity = 0.1595
# Comparing IMG_0462.jpg and IMG_0480.jpg: Similarity = 0.1652
# Comparing IMG_0463.jpg and IMG_0464.jpg: Similarity = 0.4037
# Comparing IMG_0463.jpg and IMG_0465.jpg: Similarity = 0.3825
# Comparing IMG_0463.jpg and IMG_0466.jpg: Similarity = 0.0425
# Comparing IMG_0463.jpg and IMG_0467.jpg: Similarity = 0.0408
# Comparing IMG_0463.jpg and IMG_0469.jpg: Similarity = 0.0835
# Comparing IMG_0463.jpg and IMG_0470.jpg: Similarity = 0.0389
# Comparing IMG_0463.jpg and IMG_0472.jpg: Similarity = 0.0479
# Comparing IMG_0463.jpg and IMG_0473.jpg: Similarity = 0.0828
# Comparing IMG_0463.jpg and IMG_0474.jpg: Similarity = 0.0351
# Comparing IMG_0463.jpg and IMG_0475.jpg: Similarity = 0.1524
# Comparing IMG_0463.jpg and IMG_0476.jpg: Similarity = 0.2071
# Comparing IMG_0463.jpg and IMG_0477.jpg: Similarity = 0.1675
# Comparing IMG_0463.jpg and IMG_0478.jpg: Similarity = 0.1517
# Comparing IMG_0463.jpg and IMG_0480.jpg: Similarity = 0.1450
# Comparing IMG_0464.jpg and IMG_0465.jpg: Similarity = 0.7462
# Comparing IMG_0464.jpg and IMG_0466.jpg: Similarity = 0.0711
# Comparing IMG_0464.jpg and IMG_0467.jpg: Similarity = 0.0631
# Comparing IMG_0464.jpg and IMG_0469.jpg: Similarity = 0.0847
# Comparing IMG_0464.jpg and IMG_0470.jpg: Similarity = 0.0568
# Comparing IMG_0464.jpg and IMG_0472.jpg: Similarity = 0.0738
# Comparing IMG_0464.jpg and IMG_0473.jpg: Similarity = 0.0492
# Comparing IMG_0464.jpg and IMG_0474.jpg: Similarity = 0.0471
# Comparing IMG_0464.jpg and IMG_0475.jpg: Similarity = 0.1361
# Comparing IMG_0464.jpg and IMG_0476.jpg: Similarity = 0.1898
# Comparing IMG_0464.jpg and IMG_0477.jpg: Similarity = 0.1336
# Comparing IMG_0464.jpg and IMG_0478.jpg: Similarity = 0.1444
# Comparing IMG_0464.jpg and IMG_0480.jpg: Similarity = 0.1368
# Comparing IMG_0465.jpg and IMG_0466.jpg: Similarity = 0.0580
# Comparing IMG_0465.jpg and IMG_0467.jpg: Similarity = 0.0499
# Comparing IMG_0465.jpg and IMG_0469.jpg: Similarity = 0.0751
# Comparing IMG_0465.jpg and IMG_0470.jpg: Similarity = 0.0587
# Comparing IMG_0465.jpg and IMG_0472.jpg: Similarity = 0.0642
# Comparing IMG_0465.jpg and IMG_0473.jpg: Similarity = 0.0517
# Comparing IMG_0465.jpg and IMG_0474.jpg: Similarity = 0.0363
# Comparing IMG_0465.jpg and IMG_0475.jpg: Similarity = 0.1077
# Comparing IMG_0465.jpg and IMG_0476.jpg: Similarity = 0.1681
# Comparing IMG_0465.jpg and IMG_0477.jpg: Similarity = 0.1184
# Comparing IMG_0465.jpg and IMG_0478.jpg: Similarity = 0.1168
# Comparing IMG_0465.jpg and IMG_0480.jpg: Similarity = 0.1207
# Comparing IMG_0466.jpg and IMG_0467.jpg: Similarity = 0.8022
# Moved duplicate image to dupes folder: IMG_0467.jpg
# Comparing IMG_0466.jpg and IMG_0469.jpg: Similarity = 0.2454
# Comparing IMG_0466.jpg and IMG_0470.jpg: Similarity = 0.1810
# Comparing IMG_0466.jpg and IMG_0472.jpg: Similarity = 0.0838
# Comparing IMG_0466.jpg and IMG_0473.jpg: Similarity = 0.0959
# Comparing IMG_0466.jpg and IMG_0474.jpg: Similarity = 0.0446
# Comparing IMG_0466.jpg and IMG_0475.jpg: Similarity = 0.0522
# Comparing IMG_0466.jpg and IMG_0476.jpg: Similarity = 0.0405
# Comparing IMG_0466.jpg and IMG_0477.jpg: Similarity = 0.0331
# Comparing IMG_0466.jpg and IMG_0478.jpg: Similarity = 0.0358
# Comparing IMG_0466.jpg and IMG_0480.jpg: Similarity = 0.0405
# Comparing IMG_0467.jpg and IMG_0469.jpg: Similarity = 0.2010
# Comparing IMG_0467.jpg and IMG_0470.jpg: Similarity = 0.2055
# Comparing IMG_0467.jpg and IMG_0472.jpg: Similarity = 0.0920
# Comparing IMG_0467.jpg and IMG_0473.jpg: Similarity = 0.0962
# Comparing IMG_0467.jpg and IMG_0474.jpg: Similarity = 0.0538
# Comparing IMG_0467.jpg and IMG_0475.jpg: Similarity = 0.0554
# Comparing IMG_0467.jpg and IMG_0476.jpg: Similarity = 0.0408
# Comparing IMG_0467.jpg and IMG_0477.jpg: Similarity = 0.0316
# Comparing IMG_0467.jpg and IMG_0478.jpg: Similarity = 0.0362
# Comparing IMG_0467.jpg and IMG_0480.jpg: Similarity = 0.0425
# Comparing IMG_0469.jpg and IMG_0470.jpg: Similarity = 0.0775
# Comparing IMG_0469.jpg and IMG_0472.jpg: Similarity = 0.0877
# Comparing IMG_0469.jpg and IMG_0473.jpg: Similarity = 0.0552
# Comparing IMG_0469.jpg and IMG_0474.jpg: Similarity = 0.0546
# Comparing IMG_0469.jpg and IMG_0475.jpg: Similarity = 0.0812
# Comparing IMG_0469.jpg and IMG_0476.jpg: Similarity = 0.0827
# Comparing IMG_0469.jpg and IMG_0477.jpg: Similarity = 0.0537
# Comparing IMG_0469.jpg and IMG_0478.jpg: Similarity = 0.0572
# Comparing IMG_0469.jpg and IMG_0480.jpg: Similarity = 0.0525
# Comparing IMG_0470.jpg and IMG_0472.jpg: Similarity = 0.0655
# Comparing IMG_0470.jpg and IMG_0473.jpg: Similarity = 0.1262
# Comparing IMG_0470.jpg and IMG_0474.jpg: Similarity = 0.0582
# Comparing IMG_0470.jpg and IMG_0475.jpg: Similarity = 0.0322
# Comparing IMG_0470.jpg and IMG_0476.jpg: Similarity = 0.0292
# Comparing IMG_0470.jpg and IMG_0477.jpg: Similarity = 0.0321
# Comparing IMG_0470.jpg and IMG_0478.jpg: Similarity = 0.0357
# Comparing IMG_0470.jpg and IMG_0480.jpg: Similarity = 0.0394
# Comparing IMG_0472.jpg and IMG_0473.jpg: Similarity = 0.0575
# Comparing IMG_0472.jpg and IMG_0474.jpg: Similarity = 0.0797
# Comparing IMG_0472.jpg and IMG_0475.jpg: Similarity = 0.0766
# Comparing IMG_0472.jpg and IMG_0476.jpg: Similarity = 0.0648
# Comparing IMG_0472.jpg and IMG_0477.jpg: Similarity = 0.0653
# Comparing IMG_0472.jpg and IMG_0478.jpg: Similarity = 0.0743
# Comparing IMG_0472.jpg and IMG_0480.jpg: Similarity = 0.0803
# Comparing IMG_0473.jpg and IMG_0474.jpg: Similarity = 0.1108
# Comparing IMG_0473.jpg and IMG_0475.jpg: Similarity = 0.0536
# Comparing IMG_0473.jpg and IMG_0476.jpg: Similarity = 0.0662
# Comparing IMG_0473.jpg and IMG_0477.jpg: Similarity = 0.1028
# Comparing IMG_0473.jpg and IMG_0478.jpg: Similarity = 0.0905
# Comparing IMG_0473.jpg and IMG_0480.jpg: Similarity = 0.0837
# Comparing IMG_0474.jpg and IMG_0475.jpg: Similarity = 0.0387
# Comparing IMG_0474.jpg and IMG_0476.jpg: Similarity = 0.0283
# Comparing IMG_0474.jpg and IMG_0477.jpg: Similarity = 0.0513
# Comparing IMG_0474.jpg and IMG_0478.jpg: Similarity = 0.0569
# Comparing IMG_0474.jpg and IMG_0480.jpg: Similarity = 0.0500
# Comparing IMG_0475.jpg and IMG_0476.jpg: Similarity = 0.5432
# Moved duplicate image to dupes folder: IMG_0476.jpg
# Comparing IMG_0475.jpg and IMG_0477.jpg: Similarity = 0.1303
# Comparing IMG_0475.jpg and IMG_0478.jpg: Similarity = 0.1590
# Comparing IMG_0475.jpg and IMG_0480.jpg: Similarity = 0.1639
# Comparing IMG_0476.jpg and IMG_0477.jpg: Similarity = 0.1377
# Comparing IMG_0476.jpg and IMG_0478.jpg: Similarity = 0.1665
# Comparing IMG_0476.jpg and IMG_0480.jpg: Similarity = 0.1466
# Comparing IMG_0477.jpg and IMG_0478.jpg: Similarity = 0.7993
# Moved duplicate image to dupes folder: IMG_0478.jpg
# Comparing IMG_0477.jpg and IMG_0480.jpg: Similarity = 0.7748
# Moved duplicate image to dupes folder: IMG_0480.jpg
# Comparing IMG_0478.jpg and IMG_0480.jpg: Similarity = 0.7366
# Moved kept image to best folder: IMG_0333(1).jpg
# Moved kept image to best folder: IMG_0334.jpg
# Moved kept image to best folder: IMG_0339.jpg
# Moved kept image to best folder: IMG_0341.jpg
# Moved kept image to best folder: IMG_0345.JPG
# Moved kept image to best folder: IMG_0350.jpg
# Moved kept image to best folder: IMG_0355.jpg
# Moved kept image to best folder: IMG_0358.jpg
# Moved kept image to best folder: IMG_0361.jpg
# Moved kept image to best folder: IMG_0366.jpg
# Moved kept image to best folder: IMG_0371.JPG
# Moved kept image to best folder: IMG_0376.JPG
# Moved kept image to best folder: IMG_0382.jpg
# Moved kept image to best folder: IMG_0383.jpg
# Moved kept image to best folder: IMG_0384.jpg
# Moved kept image to best folder: IMG_0386.jpg
# Moved kept image to best folder: IMG_0389.jpg
# Moved kept image to best folder: IMG_0390.jpg
# Moved kept image to best folder: IMG_0391.jpg
# Moved kept image to best folder: IMG_0392.jpg
# Moved kept image to best folder: IMG_0393.jpg
# Moved kept image to best folder: IMG_0395.jpg
# Moved kept image to best folder: IMG_0401.jpg
# Moved kept image to best folder: IMG_0406.jpg
# Moved kept image to best folder: IMG_0407.jpg
# Moved kept image to best folder: IMG_0408.jpg
# Moved kept image to best folder: IMG_0409.jpg
# Moved kept image to best folder: IMG_0414.JPG
# Moved kept image to best folder: IMG_0416.jpg
# Moved kept image to best folder: IMG_0419.jpg
# Moved kept image to best folder: IMG_0420.jpg
# Moved kept image to best folder: IMG_0422.jpg
# Moved kept image to best folder: IMG_0424.jpg
# Moved kept image to best folder: IMG_0431.jpg
# Moved kept image to best folder: IMG_0438.jpg
# Moved kept image to best folder: IMG_0439.jpg
# Moved kept image to best folder: IMG_0442.jpg
# Moved kept image to best folder: IMG_0447.jpg
# Moved kept image to best folder: IMG_0449.jpg
# Moved kept image to best folder: IMG_0450.jpg
# Moved kept image to best folder: IMG_0452.jpg
# Moved kept image to best folder: IMG_0453.jpg
# Moved kept image to best folder: IMG_0456.jpg
# Moved kept image to best folder: IMG_0458.jpg
# Moved kept image to best folder: IMG_0462.jpg
# Moved kept image to best folder: IMG_0463.jpg
# Moved kept image to best folder: IMG_0464.jpg
# Moved kept image to best folder: IMG_0466.jpg
# Moved kept image to best folder: IMG_0469.jpg
# Moved kept image to best folder: IMG_0470.jpg
# Moved kept image to best folder: IMG_0472.jpg
# Moved kept image to best folder: IMG_0473.jpg
# Moved kept image to best folder: IMG_0474.jpg
# Moved kept image to best folder: IMG_0475.jpg
# Moved kept image to best folder: IMG_0477.jpg

# %% [markdown]
# # Face recognition

# %%
import face_recognition
import os
import shutil
from PIL import Image

# %% [markdown]
# # Function to Detect and Extract Features from Input Image

# %%
def get_person_encoding(image_path):
    """
    Extract face encoding (features) from the input image.
    If multiple faces are found, we'll return the first face encoding.
    """
    try:
        image = face_recognition.load_image_file(image_path)
        face_encodings = face_recognition.face_encodings(image)

        if len(face_encodings) > 0:
            return face_encodings[0]  # Return the first face's encoding
        else:
            print(f"No faces found in {image_path}")
            return None
    except Exception as e:
        print(f"Error processing {image_path}: {e}")
        return None

# %% [markdown]
#  # Function to Identify and Move Matching Images

# %%
def move_matching_images(person_image_path, person_name, search_folder, dupes_folder, output_folder):
    """
    Search through the images in the search_folder, match faces with the input image (person_image_path),
    and move matching images to a folder named after the person.
    """
    # Get the person's face encoding
    person_encoding = get_person_encoding(person_image_path)
    if person_encoding is None:
        print(f"Could not get face encoding for {person_name}.")
        return
    
    # Create folder for the person if it doesn't exist
    person_folder = os.path.join(output_folder, person_name)
    os.makedirs(person_folder, exist_ok=True)

    # Search for images in the search_folder (excluding dupes)
    for root, _, files in os.walk(search_folder):
        if dupes_folder in root:
            continue  # Skip the dupes folder
        
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_path = os.path.join(root, file)
                
                try:
                    # Load the image and extract face encodings
                    image = face_recognition.load_image_file(image_path)
                    face_encodings = face_recognition.face_encodings(image)

                    # Compare each face encoding with the target person's encoding
                    for face_encoding in face_encodings:
                        match = face_recognition.compare_faces([person_encoding], face_encoding, tolerance=0.6)
                        if match[0]:
                            # Move image if a match is found
                            shutil.move(image_path, os.path.join(person_folder, file))
                            print(f"Moved {file} to {person_folder}")
                            break  # Move on to the next image after finding a match
                except Exception as e:
                    print(f"Error processing {image_path}: {e}")

# %% [markdown]
# # Testing

# %%
import os
import shutil
import face_recognition

# Get user inputs for the reference images and person's name
reference_images = input("Enter the filenames of the reference images (comma-separated): ").split(',')
person_name = input("Enter the name of the person: ")

# Paths
search_folder = r'C:\Users\sulik\Machine-Learning\CloneCatch\images'  # Folder where images are stored
best_folder = os.path.join(search_folder, 'best')  # Folder for best images
output_folder = os.path.join(r'C:\Users\sulik\Machine-Learning\CloneCatch', person_name)  # Folder created with the person's name

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Load face encodings for each reference image
person_encodings = []

for img_filename in reference_images:
    img_filename = img_filename.strip()  # Clean up whitespace
    person_image_path = os.path.join(search_folder, img_filename)
    person_image_path_best = os.path.join(best_folder, img_filename)

    # Check if the image file exists in either the 'images' or 'best' folder
    if os.path.exists(person_image_path):
        print(f"Reference image {img_filename} found in {search_folder}.")
        person_image = face_recognition.load_image_file(person_image_path)
    elif os.path.exists(person_image_path_best):
        print(f"Reference image {img_filename} found in {best_folder}.")
        person_image = face_recognition.load_image_file(person_image_path_best)
    else:
        print(f"Error: Reference image {img_filename} not found in {search_folder} or {best_folder}.")
        continue  # Skip this reference image if not found

    # Get the face encodings
    encodings = face_recognition.face_encodings(person_image)
    
    # Ensure at least one face encoding is found
    if len(encodings) > 0:
        person_encodings.append(encodings[0])
        print(f"Encoding generated for {img_filename}.")
    else:
        print(f"No face found in {img_filename}. Skipping.")

# Function to search and move matching images
def search_and_move_images(folder_path):
    for image_file in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_file)
        
        # Process only image files
        if os.path.isfile(image_path):
            # Load the current image and get its face encodings
            current_image = face_recognition.load_image_file(image_path)
            current_encodings = face_recognition.face_encodings(current_image)
            
            if len(current_encodings) == 0:
                print(f"No faces found in {image_file}. Skipping.")
                continue  # Skip this image if no faces are found
            
            # Check if any face encoding matches any of the person's encodings
            for current_encoding in current_encodings:
                matches = face_recognition.compare_faces(person_encodings, current_encoding)
                
                if True in matches:
                    # If a match is found, move the image to the output folder
                    output_image_path = os.path.join(output_folder, image_file)
                    shutil.copy(image_path, output_image_path)
                    print(f"Copied {image_file} to {output_folder}.")
                    break  # Move to the next image after finding a match

# Search for matching images in both the main search folder and the 'best' folder
print(f"Searching for matching images in {search_folder}...")
search_and_move_images(search_folder)

# Check if the 'best' folder exists and search it as well
if os.path.exists(best_folder):
    print(f"Searching for matching images in {best_folder}...")
    search_and_move_images(best_folder)

print("Search complete.")
# Out:
# Enter the filenames of the reference images (comma-separated): IMG_0438.jpg
# Enter the name of the person: Prateesh
# Reference image IMG_0438.jpg found in C:\Users\sulik\Machine-Learning\CloneCatch\images\best.
# Encoding generated for IMG_0438.jpg.
# Searching for matching images in C:\Users\sulik\Machine-Learning\CloneCatch\images...
# Searching for matching images in C:\Users\sulik\Machine-Learning\CloneCatch\images\best...
# No faces found in IMG_0334.jpg. Skipping.
# No faces found in IMG_0339.jpg. Skipping.
# No faces found in IMG_0361.jpg. Skipping.
# Copied IMG_0376.JPG to C:\Users\sulik\Machine-Learning\CloneCatch\Prateesh.
# No faces found in IMG_0389.jpg. Skipping.
# No faces found in IMG_0392.jpg. Skipping.
# Copied IMG_0395.jpg to C:\Users\sulik\Machine-Learning\CloneCatch\Prateesh.
# No faces found in IMG_0406.jpg. Skipping.
# No faces found in IMG_0409.jpg. Skipping.
# Copied IMG_0414.JPG to C:\Users\sulik\Machine-Learning\CloneCatch\Prateesh.
# Copied IMG_0422.jpg to C:\Users\sulik\Machine-Learning\CloneCatch\Prateesh.
# Copied IMG_0438.jpg to C:\Users\sulik\Machine-Learning\CloneCatch\Prateesh.
# Copied IMG_0442.jpg to C:\Users\sulik\Machine-Learning\CloneCatch\Prateesh.
# No faces found in IMG_0450.jpg. Skipping.
# No faces found in IMG_0452.jpg. Skipping.
# Copied IMG_0453.jpg to C:\Users\sulik\Machine-Learning\CloneCatch\Prateesh.
# No faces found in IMG_0456.jpg. Skipping.
# Copied IMG_0458.jpg to C:\Users\sulik\Machine-Learning\CloneCatch\Prateesh.
# No faces found in IMG_0462.jpg. Skipping.
# No faces found in IMG_0463.jpg. Skipping.
# No faces found in IMG_0464.jpg. Skipping.
# No faces found in IMG_0466.jpg. Skipping.
# No faces found in IMG_0470.jpg. Skipping.
# No faces found in IMG_0472.jpg. Skipping.
# No faces found in IMG_0473.jpg. Skipping.
# Search complete.
